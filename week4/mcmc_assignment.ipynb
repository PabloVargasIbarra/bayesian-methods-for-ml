# %% [markdown]
# # First things first
# Click **File -> Save a copy in Drive** and click **Open in new tab** in the pop-up window to save your progress in Google Drive.

# %% [markdown]
# # Using PyMC3

# %% [markdown]
# In this assignment, we will learn how to use a library for probabilistic programming and inference called <a href="http://docs.pymc.io/">PyMC3</a>.

# %% [markdown]
# ### Setup
# Loading auxiliary files and importing the necessary libraries.

# %%
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False
if IN_COLAB:
    print("Downloading Colab files")
    ! shred -u setup_google_colab.py
    ! wget https://raw.githubusercontent.com/hse-aml/bayesian-methods-for-ml/master/setup_google_colab.py -O setup_google_colab.py
    import setup_google_colab
    setup_google_colab.load_data_week4()

# %%
import numpy as np
import pandas as pd
import numpy.random as rnd
import seaborn as sns
from matplotlib import animation
import pymc3 as pm
from w4_grader import MCMCGrader
# %pylab inline
# Out:
# /Users/pablovargas/anaconda3/lib/python3.7/site-packages/theano/configdefaults.py:560: UserWarning: DeprecationWarning: there is no c++ compiler.This is deprecated and with Theano 0.11 a c++ compiler will be mandatory
#   warnings.warn("DeprecationWarning: there is no c++ compiler."
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Grading
# We will create a grader instance below and use it to collect your answers. Note that these outputs will be stored locally inside grader and will be uploaded to the platform only after running submitting function in the last part of this assignment. If you want to make a partial submission, you can run that cell anytime you want.

# %%
grader = MCMCGrader()

# %% [markdown]
# ## Task 1. Alice and Bob
#
# Alice and Bob are trading on the market. Both of them are selling the Thing and want to get as high profit as possible.
# Every hour they check out with each other's prices and adjust their prices to compete on the market. Although they have different strategies for price setting.
#
# **Alice**: takes Bob's price during the **previous** hour, multiply by 0.6, add \\$90, add Gaussian noise from $N(0, 20^2)$.
#
# **Bob**: takes Alice's price during the **current** hour, multiply by 1.2 and subtract \\$20, add Gaussian noise from $N(0, 10^2)$.
#
# The problem is to find the joint distribution of Alice and Bob's prices after many hours of such an experiment.

# %% [markdown]
# ### Task 1.1
#
# Implement the `run_simulation` function according to the description above.

# %%
def run_simulation(alice_start_price=300.0, bob_start_price=300.0, seed=42, num_hours=10000, burnin=1000):
    """Simulates an evolution of prices set by Bob and Alice.
    
    The function should simulate Alice and Bob behavior for `burnin' hours, then ignore the obtained
    simulation results, and then simulate it for `num_hours' more.
    The initial burnin (also sometimes called warmup) is done to make sure that the distribution stabilized.
    
    Please don't change the signature of the function.
    
    Returns:
        two lists, with Alice and with Bob prices. Both lists should be of length num_hours.
    """
    np.random.seed(seed)

    alice_prices = [alice_start_price]
    bob_prices = [bob_start_price]
    
    for i in range(burnin + num_hours - 1):
        alice_prices.append(bob_prices[i] * 0.6 + 90 + numpy.random.normal(loc=0, scale=20))
        bob_prices.append(alice_prices[i+1] * 1.2 - 20 + numpy.random.normal(loc=0, scale=10))
        
    return alice_prices[burnin:], bob_prices[burnin:]

# %%
alice_prices, bob_prices = run_simulation(alice_start_price=300, bob_start_price=300, seed=42, num_hours=3, burnin=1)
if len(alice_prices) != 3:
    raise RuntimeError('Make sure that the function returns `num_hours` data points.')
grader.submit_simulation_trajectory(alice_prices, bob_prices)
# Out:
# Current answer for task 1.1 (Alice trajectory) is: 279.93428306022463  291.67686875834846
# Current answer for task 1.1 (Bob trajectory) is: 314.5384966605577  345.2425410740984

# %% [markdown]
# ### Task 1.2
# What is the average price for Alice and Bob after the burn-in period? Whose prices are higher?

# %%
alice_prices, bob_prices = run_simulation(alice_start_price=300, bob_start_price=300, seed=42, 
                                          num_hours=10000, burnin=1000)
average_alice_price = np.mean(alice_prices)
average_bob_price = np.mean(bob_prices)

grader.submit_simulation_mean(average_alice_price, average_bob_price)
# Out:
# Current answer for task 1.2 (Alice mean) is: 278.85416992423353
# Current answer for task 1.2 (Bob mean) is: 314.6064116545574

# %% [markdown]
# ### Task 1.3
#
# Let's look at the 2-d histogram of prices, computed using kernel density estimation.

# %%
data = np.array(run_simulation())
sns.jointplot(data[0, :], data[1, :], stat_func=None, kind='kde')

# %% [markdown]
# Clearly, the prices of Bob and Alce are highly correlated. What is the Pearson correlation coefficient of Alice and Bob prices?

# %%
correlation = np.corrcoef(alice_prices, bob_prices)[0][1]

grader.submit_simulation_correlation(correlation)
# Out:
# Current answer for task 1.3 (Bob and Alice prices correlation) is: 0.9636099866766943

# %% [markdown]
# ### Task 1.4

# %% [markdown]
# We observe an interesting effect here: seems like the bivariate distribution of Alice and Bob prices converges to a correlated bivariate Gaussian distribution.
#
# Let's check, whether the results change if we use different random seed and starting points.

# %%
# Pick different starting prices, e.g 10, 1000, 10000 for Bob and Alice. 
# Does the joint distribution of the two prices depend on these parameters?
POSSIBLE_ANSWERS = {
    0: 'Depends on random seed and starting prices', 
    1: 'Depends only on random seed',
    2: 'Depends only on starting prices',
    3: 'Does not depend on random seed and starting prices'
}

idx = 3
answer = POSSIBLE_ANSWERS[idx]
grader.submit_simulation_depends(answer)
# Out:
# Current answer for task 1.4 (depends on the random data or not) is: Does not depend on random seed and starting prices

# %% [markdown]
# ## Task 2. Logistic regression with PyMC3
#
# Logistic regression is a powerful model that allows you to analyze how a set of features affects some binary target label. Posterior distribution over the weights gives us an estimation of the influence of each particular feature on the probability of the target being equal to one. But most importantly, posterior distribution gives us the interval estimates for each weight of the model. This is very important for data analysis when you want to not only provide a good model but also estimate the uncertainty of your conclusions.
#
# In this task, we will learn how to use PyMC3 library to perform approximate Bayesian inference for logistic regression.
#
# This part of the assignment is based on the logistic regression tutorial by Peadar Coyle and J. Benjamin Cook.

# %% [markdown]
# ### Logistic regression.
#
# The problem here is to model how the probability that a person has salary $\geq$ \\$50K is affected by his/her age, education, sex and other features.
#
# Let $y_i = 1$ if i-th person's salary is $\geq$ \\$50K and $y_i = 0$ otherwise. Let $x_{ij}$ be $j$-th feature of $i$-th person.
#
# Logistic regression models this probabilty in the following way:
#
# $$p(y_i = 1 \mid \beta) = \sigma (\beta_1 x_{i1} + \beta_2 x_{i2} + \dots + \beta_k x_{ik} ), $$
#
# where $\sigma(t) = \frac1{1 + e^{-t}}$

# %% [markdown]
# #### Odds ratio.
# Let's try to answer the following question: does the gender of a person affects his or her salary? To do it we will use the concept of *odds*.
#
# If we have a binary random variable $y$ (which may indicate whether a person makes \\$50K) and if the probabilty of the positive outcome $p(y = 1)$ is for example 0.8, we will say that the *odds* are 4 to 1 (or just 4 for short), because succeding is 4 time more likely than failing $\frac{p(y = 1)}{p(y = 0)} = \frac{0.8}{0.2} = 4$.
#
# Now, let's return to the effect of gender on the salary. Let's compute the **ratio** between the odds of a male having salary $\geq $ \\$50K and the odds of a female (with the same level of education, experience and everything else) having salary $\geq$ \\$50K. The first feature of each person in the dataset is gender. Specifically, $x_{i1} = 0$ if the person is female and $x_{i1} = 1$ otherwise. Consider two people $i$ and $j$ having all but one features the same with the only difference in $x_{i1} \neq x_{j1}$.
#
# If the logistic regression model above estimates the probabilities exactly, the odds for a male will be (check it!):
# $$
# \frac{p(y_i = 1 \mid x_{i1}=1, x_{i2}, \ldots, x_{ik})}{p(y_i = 0 \mid x_{i1}=1, x_{i2}, \ldots, x_{ik})} = \frac{\sigma(\beta_1 + \beta_2 x_{i2} + \ldots)}{1 - \sigma(\beta_1 + \beta_2 x_{i2} + \ldots)} = \exp(\beta_1 + \beta_2 x_{i2} + \ldots)
# $$
#
# Now the ratio of the male and female odds will be:
# $$
# \frac{\exp(\beta_1 \cdot 1 + \beta_2 x_{i2} + \ldots)}{\exp(\beta_1 \cdot 0 + \beta_2 x_{i2} + \ldots)} = \exp(\beta_1)
# $$
#
# So given the correct logistic regression model, we can estimate odds ratio for some feature (gender in this example) by just looking at the corresponding coefficient. But of course, even if all the logistic regression assumptions are met we cannot estimate the coefficient exactly from real-world data, it's just too noisy. So it would be really nice to build an interval estimate, which would tell us something along the lines "with probability 0.95 the odds ratio is greater than 0.8 and less than 1.2, so we cannot conclude that there is any gender discrimination in the salaries" (or vice versa, that "with probability 0.95 the odds ratio is greater than 1.5 and less than 1.9 and the discrimination takes place because a male has at least 1.5 higher probability to get >$50k than a female with the same level of education, age, etc."). In Bayesian statistics, this interval estimate is called *credible interval*.
#
# Unfortunately, it's impossible to compute this credible interval analytically. So let's use MCMC for that!
#
# #### Credible interval
# A credible interval for the value of $\exp(\beta_1)$ is an interval $[a, b]$ such that $p(a \leq \exp(\beta_1) \leq b \mid X_{\text{train}}, y_{\text{train}})$ is $0.95$ (or some other predefined value). To compute the interval, we need access to the posterior distribution $p(\exp(\beta_1) \mid X_{\text{train}}, y_{\text{train}})$.
#
# Lets for simplicity focus on the posterior on the parameters $p(\beta_1 \mid X_{\text{train}}, y_{\text{train}})$ since if we compute it, we can always find $[a, b]$ such that $p(\log a \leq \beta_1 \leq \log b \mid X_{\text{train}}, y_{\text{train}}) = p(a \leq \exp(\beta_1) \leq b \mid X_{\text{train}}, y_{\text{train}}) = 0.95$

# %% [markdown]
# ### Task 2.1 MAP inference

# %% [markdown]
# Let's read the dataset. This is a post-processed version of the [UCI Adult dataset](http://archive.ics.uci.edu/ml/datasets/Adult).

# %%
data = pd.read_csv("adult_us_postprocessed.csv")
data.head()
# Out:
#        sex  age  educ  hours  income_more_50K
# 0     Male   39    13     40                0
# 1     Male   50    13     13                0
# 2     Male   38     9     40                0
# 3     Male   53     7     40                0
# 4   Female   28    13     40                0

# %% [markdown]
# Each row of the dataset is a person with his (her) features. The last column is the target variable $y$. One indicates that this person's annual salary is more than $50K.
#
# First of all let's set up a Bayesian logistic regression model (i.e. define priors on the parameters $\alpha$ and $\beta$ of the model) that predicts the value of "income_more_50K" based on person's age and education:
#
# $$
# p(y = 1 \mid \alpha, \beta_1, \beta_2) = \sigma(\alpha + \beta_1 x_1 + \beta_2 x_2) \\
# \alpha \sim N(0, 100^2) \\
# \beta_1 \sim N(0, 100^2) \\
# \beta_2 \sim N(0, 100^2), \\
# $$
#
# where $x_1$ is a person's age, $x_2$ is his/her level of education, y indicates his/her level of income, $\alpha$, $\beta_1$ and $\beta_2$ are paramters of the model.

# %%
with pm.Model() as manual_logistic_model:
    # Declare pymc random variables for logistic regression coefficients with uninformative 
    # prior distributions N(0, 100^2) on each weight using pm.Normal. 
    # Don't forget to give each variable a unique name.
    
    alpha = pm.Normal('alpha', mu=0, sd=100)
    b1 = pm.Normal('beta1', mu=0, sd=100)
    b2 = pm.Normal('beta2', mu=0, sd=100)
    
    # Thansform these random variables into vector of probabilities p(y_i=1) using logistic regression model specified 
    # above. PyMC random variables are theano shared variables and support simple mathematical operations.
    # For example:
    # z = pm.Normal('x', 0, 1) * np.array([1, 2, 3]) + pm.Normal('y', 0, 1) * np.array([4, 5, 6])`
    # is a correct PyMC expression.
    # Use pm.invlogit for the sigmoid function.
    
    x_1 = np.array(data['age'])
    x_2 = np.array(data['educ'])
    z = pm.invlogit(alpha + b1 * x_1 + b2 * x_2)
    
    # Declare PyMC Bernoulli random vector with probability of success equal to the corresponding value
    # given by the sigmoid function.
    # Supply target vector using "observed" argument in the constructor.

    yhat = pm.Bernoulli('yhat', p=z, observed=data['income_more_50K'])
    
    # Use pm.find_MAP() to find the maximum a-posteriori estimate for the vector of logistic regression weights.
    map_estimate = pm.find_MAP()
    print(map_estimate)
# Out:
# logp = -15,349, ||grad|| = 57,813: 100%|██████████| 30/30 [05:32<00:00, 11.09s/it]
# {'alpha': array(-6.74809299), 'beta1': array(0.04348244), 'beta2': array(0.3621089)}

# %% [markdown]
# Sumbit MAP estimations of corresponding coefficients:

# %%
with pm.Model() as logistic_model:
    # There's a simpler interface for generalized linear models in pymc3. 
    # Try to train the same model using pm.glm.GLM.from_formula.
    # Do not forget to specify that the target variable is binary (and hence follows Binomial distribution).
    pm.glm.GLM.from_formula("income_more_50K ~ age + educ", data, family='binomial')
    map_estimate = pm.find_MAP()
    print(map_estimate)

# %%
beta_age_coefficient = 0.04348244
beta_education_coefficient = 0.3621089
grader.submit_pymc_map_estimates(beta_age_coefficient, beta_education_coefficient)
# Out:
# Current answer for task 2.1 (MAP for age coef) is: 0.04348244
# Current answer for task 2.1 (MAP for aducation coef) is: 0.3621089

# %% [markdown]
# ### Task 2.2 MCMC

# %% [markdown]
# To find credible regions let's perform MCMC inference.

# %%
# You will need the following function to visualize the sampling process.
# You don't need to change it.
def plot_traces(traces, burnin=200):
    ''' 
    Convenience function:
    Plot traces with overlaid means and values
    '''
    
    ax = pm.traceplot(traces[burnin:], figsize=(12,len(traces.varnames)*1.5),
        lines={k: v['mean'] for k, v in pm.summary(traces[burnin:]).iterrows()})

    for i, mn in enumerate(pm.summary(traces[burnin:])['mean']):
        ax[i,0].annotate('{:.2f}'.format(mn), xy=(mn,0), xycoords='data'
                    ,xytext=(5,10), textcoords='offset points', rotation=90
                    ,va='bottom', fontsize='large', color='#AA0022')

# %% [markdown]
# #### Metropolis-Hastings
# Let's use the Metropolis-Hastings algorithm for finding the samples from the posterior distribution.
#
# Once you wrote the code, explore the hyperparameters of Metropolis-Hastings such as the proposal distribution variance to speed up the convergence. You can use `plot_traces` function in the next cell to visually inspect the convergence.
#
# You may also use MAP-estimate to initialize the sampling scheme to speed things up. This will make the warmup (burn-in) period shorter since you will start from a probable point.

# %%
with pm.Model() as logistic_model:
    # Since it is unlikely that the dependency between the age and salary is linear, we will include age squared
    # into features so that we can model dependency that favors certain ages.
    # Train Bayesian logistic regression model on the following features: sex, age, age^2, educ, hours
    # Use pm.sample to run MCMC to train this model.
    # To specify the particular sampler method (Metropolis-Hastings) to pm.sample,
    # use `pm.Metropolis`.
    # Train your model for 400 samples.
    # Save the output of pm.sample to a variable: this is the trace of the sampling procedure and will be used
    # to estimate the statistics of the posterior distribution.
    data['age2'] = data['age']**2
    pm.glm.GLM.from_formula("income_more_50K ~ sex + age + age2 + educ + hours", data, family='binomial')
    trace = pm.sample(draws=400, step=pm.Metropolis(), init = 'advi_map', cores=1, tune=1)
# Out:
# Only 400 samples in chain.
# Sequential sampling (2 chains in 1 job)
# CompoundStep
# >Metropolis: [hours]
# >Metropolis: [educ]
# >Metropolis: [age2]
# >Metropolis: [age]
# >Metropolis: [sex[T. Male]]
# >Metropolis: [Intercept]
#
#
# Sampling chain 0, 0 divergences:   0%|          | 0/401 [00:00<?, ?it/s]
#
# Sampling chain 0, 0 divergences:   0%|          | 1/401 [00:22<2:28:10, 22.23s/it]
#
# Sampling chain 0, 0 divergences:   0%|          | 2/401 [00:45<2:30:04, 22.57s/it]
#
# Sampling chain 0, 0 divergences:   1%|          | 3/401 [01:09<2:32:16, 22.96s/it]
#
# Sampling chain 0, 0 divergences:   1%|          | 4/401 [01:33<2:34:07, 23.29s/it]
#
# Sampling chain 0, 0 divergences:   1%|          | 5/401 [01:57<2:34:29, 23.41s/it]
#
# Sampling chain 0, 0 divergences:   1%|▏         | 6/401 [02:19<2:32:05, 23.10s/it]
#
# Sampling chain 0, 0 divergences:   2%|▏         | 7/401 [02:41<2:29:38, 22.79s/it]
#
# Sampling chain 0, 0 divergences:   2%|▏         | 8/401 [03:04<2:28:40, 22.70s/it]
#
# Sampling chain 0, 0 divergences:   2%|▏         | 9/401 [03:25<2:26:01, 22.35s/it]
#
# Sampling chain 0, 0 divergences:   2%|▏         | 10/401 [03:47<2:25:07, 22.27s/it]
#
# Sampling chain 0, 0 divergences:   3%|▎         | 11/401 [04:09<2:23:31, 22.08s/it]
#
# Sampling chain 0, 0 divergences:   3%|▎         | 12/401 [04:31<2:22:38, 22.00s/it]
#
# Sampling chain 0, 0 divergences:   3%|▎         | 13/401 [04:53<2:22:09, 21.98s/it]
#
# Sampling chain 0, 0 divergences:   3%|▎         | 14/401 [05:15<2:22:10, 22.04s/it]
#
# Sampling chain 0, 0 divergences:   4%|▎         | 15/401 [05:37<2:21:36, 22.01s/it]
#
# Sampling chain 0, 0 divergences:   4%|▍         | 16/401 [05:59<2:22:12, 22.16s/it]
#
# Sampling chain 0, 0 divergences:   4%|▍         | 17/401 [06:21<2:21:08, 22.05s/it]
#
# Sampling chain 0, 0 divergences:   4%|▍         | 18/401 [06:43<2:21:19, 22.14s/it]
#
# Sampling chain 0, 0 divergences:   5%|▍         | 19/401 [07:05<2:20:25, 22.06s/it]
#
# Sampling chain 0, 0 divergences:   5%|▍         | 20/401 [07:28<2:21:20, 22.26s/it]
#
# Sampling chain 0, 0 divergences:   5%|▌         | 21/401 [07:50<2:21:11, 22.29s/it]
#
# Sampling chain 0, 0 divergences:   5%|▌         | 22/401 [08:12<2:18:58, 22.00s/it]
#
# Sampling chain 0, 0 divergences:   6%|▌         | 23/401 [08:33<2:18:00, 21.91s/it]
#
# Sampling chain 0, 0 divergences:   6%|▌         | 24/401 [08:55<2:17:06, 21.82s/it]
#
# Sampling chain 0, 0 divergences:   6%|▌         | 25/401 [09:17<2:16:31, 21.79s/it]
#
# Sampling chain 0, 0 divergences:   6%|▋         | 26/401 [09:38<2:15:27, 21.67s/it]
#
# Sampling chain 0, 0 divergences:   7%|▋         | 27/401 [10:01<2:16:28, 21.90s/it]
#
# Sampling chain 0, 0 divergences:   7%|▋         | 28/401 [10:23<2:16:47, 22.00s/it]
#
# Sampling chain 0, 0 divergences:   7%|▋         | 29/401 [10:45<2:16:53, 22.08s/it]
#
# Sampling chain 0, 0 divergences:   7%|▋         | 30/401 [11:07<2:16:31, 22.08s/it]
#
# Sampling chain 0, 0 divergences:   8%|▊         | 31/401 [11:29<2:16:25, 22.12s/it]
#
# Sampling chain 0, 0 divergences:   8%|▊         | 32/401 [11:51<2:15:25, 22.02s/it]
#
# Sampling chain 0, 0 divergences:   8%|▊         | 33/401 [12:13<2:15:01, 22.02s/it]
#
# Sampling chain 0, 0 divergences:   8%|▊         | 34/401 [12:35<2:14:26, 21.98s/it]
#
# Sampling chain 0, 0 divergences:   9%|▊         | 35/401 [12:57<2:14:42, 22.08s/it]
#
# Sampling chain 0, 0 divergences:   9%|▉         | 36/401 [13:19<2:14:09, 22.05s/it]
#
# Sampling chain 0, 0 divergences:   9%|▉         | 37/401 [13:41<2:12:28, 21.84s/it]
#
# Sampling chain 0, 0 divergences:   9%|▉         | 38/401 [14:03<2:12:19, 21.87s/it]
#
# Sampling chain 0, 0 divergences:  10%|▉         | 39/401 [14:25<2:11:58, 21.87s/it]
#
# Sampling chain 0, 0 divergences:  10%|▉         | 40/401 [14:46<2:11:43, 21.89s/it]
#
# Sampling chain 0, 0 divergences:  10%|█         | 41/401 [15:09<2:12:07, 22.02s/it]
#
# Sampling chain 0, 0 divergences:  10%|█         | 42/401 [15:31<2:12:04, 22.07s/it]
#
# Sampling chain 0, 0 divergences:  11%|█         | 43/401 [15:53<2:11:38, 22.06s/it]
#
# Sampling chain 0, 0 divergences:  11%|█         | 44/401 [16:15<2:11:48, 22.15s/it]
#
# Sampling chain 0, 0 divergences:  11%|█         | 45/401 [16:37<2:11:01, 22.08s/it]
#
# Sampling chain 0, 0 divergences:  11%|█▏        | 46/401 [17:00<2:11:19, 22.20s/it]
#
# Sampling chain 0, 0 divergences:  12%|█▏        | 47/401 [17:22<2:10:21, 22.09s/it]
#
# Sampling chain 0, 0 divergences:  12%|█▏        | 48/401 [17:44<2:09:47, 22.06s/it]
#
# Sampling chain 0, 0 divergences:  12%|█▏        | 49/401 [18:05<2:09:03, 22.00s/it]
#
# Sampling chain 0, 0 divergences:  12%|█▏        | 50/401 [18:28<2:08:58, 22.05s/it]
#
# Sampling chain 0, 0 divergences:  13%|█▎        | 51/401 [18:49<2:07:23, 21.84s/it]
#
# Sampling chain 0, 0 divergences:  13%|█▎        | 52/401 [19:10<2:06:17, 21.71s/it]
#
# Sampling chain 0, 0 divergences:  13%|█▎        | 53/401 [19:33<2:07:04, 21.91s/it]
#
# Sampling chain 0, 0 divergences:  13%|█▎        | 54/401 [19:55<2:06:39, 21.90s/it]
#
# Sampling chain 0, 0 divergences:  14%|█▎        | 55/401 [20:17<2:06:17, 21.90s/it]
#
# Sampling chain 0, 0 divergences:  14%|█▍        | 56/401 [20:38<2:05:55, 21.90s/it]
#
# Sampling chain 0, 0 divergences:  14%|█▍        | 57/401 [21:00<2:04:56, 21.79s/it]
#
# Sampling chain 0, 0 divergences:  14%|█▍        | 58/401 [21:22<2:04:34, 21.79s/it]
#
# Sampling chain 0, 0 divergences:  15%|█▍        | 59/401 [21:44<2:04:30, 21.84s/it]
#
# Sampling chain 0, 0 divergences:  15%|█▍        | 60/401 [22:06<2:04:44, 21.95s/it]
#
# Sampling chain 0, 0 divergences:  15%|█▌        | 61/401 [22:27<2:03:39, 21.82s/it]
#
# Sampling chain 0, 0 divergences:  15%|█▌        | 62/401 [22:50<2:05:09, 22.15s/it]
#
# Sampling chain 0, 0 divergences:  16%|█▌        | 63/401 [23:12<2:03:55, 22.00s/it]
#
# Sampling chain 0, 0 divergences:  16%|█▌        | 64/401 [23:34<2:02:58, 21.90s/it]
#
# Sampling chain 0, 0 divergences:  16%|█▌        | 65/401 [23:56<2:03:54, 22.13s/it]
#
# Sampling chain 0, 0 divergences:  16%|█▋        | 66/401 [24:19<2:04:07, 22.23s/it]
#
# Sampling chain 0, 0 divergences:  17%|█▋        | 67/401 [24:41<2:04:16, 22.33s/it]
#
# Sampling chain 0, 0 divergences:  17%|█▋        | 68/401 [25:04<2:04:46, 22.48s/it]
#
# Sampling chain 0, 0 divergences:  17%|█▋        | 69/401 [25:26<2:03:26, 22.31s/it]
#
# Sampling chain 0, 0 divergences:  17%|█▋        | 70/401 [25:49<2:03:18, 22.35s/it]
#
# Sampling chain 0, 0 divergences:  18%|█▊        | 71/401 [26:10<2:02:14, 22.23s/it]
#
# Sampling chain 0, 0 divergences:  18%|█▊        | 72/401 [26:32<2:01:11, 22.10s/it]
#
# Sampling chain 0, 0 divergences:  18%|█▊        | 73/401 [26:54<2:00:37, 22.07s/it]
#
# Sampling chain 0, 0 divergences:  18%|█▊        | 74/401 [27:16<1:59:24, 21.91s/it]
#
# Sampling chain 0, 0 divergences:  19%|█▊        | 75/401 [27:38<1:58:50, 21.87s/it]
#
# Sampling chain 0, 0 divergences:  19%|█▉        | 76/401 [28:00<1:58:53, 21.95s/it]
#
# Sampling chain 0, 0 divergences:  19%|█▉        | 77/401 [28:22<1:58:20, 21.92s/it]
#
# Sampling chain 0, 0 divergences:  19%|█▉        | 78/401 [28:43<1:57:11, 21.77s/it]
#
# Sampling chain 0, 0 divergences:  20%|█▉        | 79/401 [29:05<1:57:36, 21.91s/it]
#
# Sampling chain 0, 0 divergences:  20%|█▉        | 80/401 [29:27<1:57:28, 21.96s/it]
#
# Sampling chain 0, 0 divergences:  20%|██        | 81/401 [29:50<1:57:41, 22.07s/it]
#
# Sampling chain 0, 0 divergences:  20%|██        | 82/401 [30:11<1:56:55, 21.99s/it]
#
# Sampling chain 0, 0 divergences:  21%|██        | 83/401 [30:33<1:56:19, 21.95s/it]
#
# Sampling chain 0, 0 divergences:  21%|██        | 84/401 [30:55<1:55:49, 21.92s/it]
#
# Sampling chain 0, 0 divergences:  21%|██        | 85/401 [31:17<1:56:04, 22.04s/it]
#
# Sampling chain 0, 0 divergences:  21%|██▏       | 86/401 [31:39<1:55:40, 22.03s/it]
#
# Sampling chain 0, 0 divergences:  22%|██▏       | 87/401 [32:02<1:56:05, 22.18s/it]
#
# Sampling chain 0, 0 divergences:  22%|██▏       | 88/401 [32:24<1:55:15, 22.09s/it]
#
# Sampling chain 0, 0 divergences:  22%|██▏       | 89/401 [32:46<1:55:03, 22.13s/it]
#
# Sampling chain 0, 0 divergences:  22%|██▏       | 90/401 [33:08<1:54:15, 22.04s/it]
#
# Sampling chain 0, 0 divergences:  23%|██▎       | 91/401 [33:30<1:53:42, 22.01s/it]
#
# Sampling chain 0, 0 divergences:  23%|██▎       | 92/401 [33:52<1:53:28, 22.03s/it]
#
# Sampling chain 0, 0 divergences:  23%|██▎       | 93/401 [34:14<1:52:44, 21.96s/it]
#
# Sampling chain 0, 0 divergences:  23%|██▎       | 94/401 [34:36<1:52:44, 22.04s/it]
#
# Sampling chain 0, 0 divergences:  24%|██▎       | 95/401 [34:58<1:52:04, 21.97s/it]
#
# Sampling chain 0, 0 divergences:  24%|██▍       | 96/401 [35:20<1:51:46, 21.99s/it]
#
# Sampling chain 0, 0 divergences:  24%|██▍       | 97/401 [35:41<1:50:35, 21.83s/it]
#
# Sampling chain 0, 0 divergences:  24%|██▍       | 98/401 [36:04<1:51:04, 22.00s/it]
#
# Sampling chain 0, 0 divergences:  25%|██▍       | 99/401 [36:26<1:50:43, 22.00s/it]
#
# Sampling chain 0, 0 divergences:  25%|██▍       | 100/401 [36:48<1:50:18, 21.99s/it]
#
# Sampling chain 0, 0 divergences:  25%|██▌       | 101/401 [37:10<1:49:58, 22.00s/it]
#
# Sampling chain 0, 0 divergences:  25%|██▌       | 102/401 [37:31<1:49:12, 21.92s/it]
#
# Sampling chain 0, 0 divergences:  26%|██▌       | 103/401 [37:53<1:49:03, 21.96s/it]
#
# Sampling chain 0, 0 divergences:  26%|██▌       | 104/401 [38:15<1:48:32, 21.93s/it]
#
# Sampling chain 0, 0 divergences:  26%|██▌       | 105/401 [38:37<1:48:24, 21.98s/it]
#
# Sampling chain 0, 0 divergences:  26%|██▋       | 106/401 [39:00<1:48:38, 22.10s/it]
#
# Sampling chain 0, 0 divergences:  27%|██▋       | 107/401 [39:22<1:48:42, 22.19s/it]
#
# Sampling chain 0, 0 divergences:  27%|██▋       | 108/401 [39:44<1:47:39, 22.05s/it]
#
# Sampling chain 0, 0 divergences:  27%|██▋       | 109/401 [40:07<1:48:27, 22.29s/it]
#
# Sampling chain 0, 0 divergences:  27%|██▋       | 110/401 [40:29<1:48:08, 22.30s/it]
#
# Sampling chain 0, 0 divergences:  28%|██▊       | 111/401 [40:51<1:47:22, 22.21s/it]
#
# Sampling chain 0, 0 divergences:  28%|██▊       | 112/401 [41:14<1:47:38, 22.35s/it]
#
# Sampling chain 0, 0 divergences:  28%|██▊       | 113/401 [41:36<1:47:22, 22.37s/it]
#
# Sampling chain 0, 0 divergences:  28%|██▊       | 114/401 [41:58<1:46:20, 22.23s/it]
#
# Sampling chain 0, 0 divergences:  29%|██▊       | 115/401 [42:20<1:46:13, 22.29s/it]
#
# Sampling chain 0, 0 divergences:  29%|██▉       | 116/401 [42:42<1:45:00, 22.11s/it]
#
# Sampling chain 0, 0 divergences:  29%|██▉       | 117/401 [43:05<1:45:08, 22.21s/it]
#
# Sampling chain 0, 0 divergences:  29%|██▉       | 118/401 [43:27<1:45:04, 22.28s/it]
#
# Sampling chain 0, 0 divergences:  30%|██▉       | 119/401 [43:49<1:43:41, 22.06s/it]
#
# Sampling chain 0, 0 divergences:  30%|██▉       | 120/401 [44:10<1:42:50, 21.96s/it]
#
# Sampling chain 0, 0 divergences:  30%|███       | 121/401 [44:32<1:42:22, 21.94s/it]
#
# Sampling chain 0, 0 divergences:  30%|███       | 122/401 [44:54<1:41:58, 21.93s/it]
#
# Sampling chain 0, 0 divergences:  31%|███       | 123/401 [45:17<1:42:21, 22.09s/it]
#
# Sampling chain 0, 0 divergences:  31%|███       | 124/401 [45:38<1:41:18, 21.94s/it]
#
# Sampling chain 0, 0 divergences:  31%|███       | 125/401 [46:00<1:41:01, 21.96s/it]
#
# Sampling chain 0, 0 divergences:  31%|███▏      | 126/401 [46:22<1:40:04, 21.83s/it]
#
# Sampling chain 0, 0 divergences:  32%|███▏      | 127/401 [46:44<1:40:43, 22.06s/it]
#
# Sampling chain 0, 0 divergences:  32%|███▏      | 128/401 [47:07<1:40:46, 22.15s/it]
#
# Sampling chain 0, 0 divergences:  32%|███▏      | 129/401 [47:28<1:39:46, 22.01s/it]
#
# Sampling chain 0, 0 divergences:  32%|███▏      | 130/401 [47:51<1:39:51, 22.11s/it]
#
# Sampling chain 0, 0 divergences:  33%|███▎      | 131/401 [48:13<1:39:19, 22.07s/it]
#
# Sampling chain 0, 0 divergences:  33%|███▎      | 132/401 [48:34<1:38:23, 21.95s/it]
#
# Sampling chain 0, 0 divergences:  33%|███▎      | 133/401 [48:56<1:37:40, 21.87s/it]
#
# Sampling chain 0, 0 divergences:  33%|███▎      | 134/401 [49:18<1:37:29, 21.91s/it]
#
# Sampling chain 0, 0 divergences:  34%|███▎      | 135/401 [49:40<1:37:10, 21.92s/it]
#
# Sampling chain 0, 0 divergences:  34%|███▍      | 136/401 [50:01<1:36:12, 21.78s/it]
#
# Sampling chain 0, 0 divergences:  34%|███▍      | 137/401 [50:24<1:36:25, 21.92s/it]
#
# Sampling chain 0, 0 divergences:  34%|███▍      | 138/401 [50:46<1:36:36, 22.04s/it]
#
# Sampling chain 0, 0 divergences:  35%|███▍      | 139/401 [51:08<1:36:09, 22.02s/it]
#
# Sampling chain 0, 0 divergences:  35%|███▍      | 140/401 [51:29<1:35:04, 21.86s/it]
#
# Sampling chain 0, 0 divergences:  35%|███▌      | 141/401 [51:51<1:34:17, 21.76s/it]
#
# Sampling chain 0, 0 divergences:  35%|███▌      | 142/401 [52:13<1:34:06, 21.80s/it]
#
# Sampling chain 0, 0 divergences:  36%|███▌      | 143/401 [52:35<1:33:47, 21.81s/it]
#
# Sampling chain 0, 0 divergences:  36%|███▌      | 144/401 [52:57<1:33:32, 21.84s/it]
#
# Sampling chain 0, 0 divergences:  36%|███▌      | 145/401 [53:19<1:33:33, 21.93s/it]
#
# Sampling chain 0, 0 divergences:  36%|███▋      | 146/401 [53:41<1:33:22, 21.97s/it]
#
# Sampling chain 0, 0 divergences:  37%|███▋      | 147/401 [54:03<1:33:16, 22.03s/it]
#
# Sampling chain 0, 0 divergences:  37%|███▋      | 148/401 [54:25<1:33:16, 22.12s/it]
#
# Sampling chain 0, 0 divergences:  37%|███▋      | 149/401 [54:48<1:33:15, 22.20s/it]
#
# Sampling chain 0, 0 divergences:  37%|███▋      | 150/401 [55:10<1:33:09, 22.27s/it]
#
# Sampling chain 0, 0 divergences:  38%|███▊      | 151/401 [55:32<1:31:51, 22.04s/it]
#
# Sampling chain 0, 0 divergences:  38%|███▊      | 152/401 [55:53<1:30:52, 21.90s/it]
#
# Sampling chain 0, 0 divergences:  38%|███▊      | 153/401 [56:16<1:31:05, 22.04s/it]
#
# Sampling chain 0, 0 divergences:  38%|███▊      | 154/401 [56:38<1:30:51, 22.07s/it]
#
# Sampling chain 0, 0 divergences:  39%|███▊      | 155/401 [57:00<1:30:54, 22.17s/it]
#
# Sampling chain 0, 0 divergences:  39%|███▉      | 156/401 [57:22<1:30:29, 22.16s/it]
#
# Sampling chain 0, 0 divergences:  39%|███▉      | 157/401 [57:44<1:29:51, 22.10s/it]
#
# Sampling chain 0, 0 divergences:  39%|███▉      | 158/401 [58:06<1:29:24, 22.07s/it]
#
# Sampling chain 0, 0 divergences:  40%|███▉      | 159/401 [58:29<1:29:26, 22.17s/it]
#
# Sampling chain 0, 0 divergences:  40%|███▉      | 160/401 [58:50<1:28:23, 22.00s/it]
#
# Sampling chain 0, 0 divergences:  40%|████      | 161/401 [59:13<1:28:26, 22.11s/it]
#
# Sampling chain 0, 0 divergences:  40%|████      | 162/401 [59:35<1:28:00, 22.09s/it]
#
# Sampling chain 0, 0 divergences:  41%|████      | 163/401 [59:56<1:27:17, 22.01s/it]
#
# Sampling chain 0, 0 divergences:  41%|████      | 164/401 [1:00:18<1:26:45, 21.97s/it]
#
# Sampling chain 0, 0 divergences:  41%|████      | 165/401 [1:00:41<1:26:46, 22.06s/it]
#
# Sampling chain 0, 0 divergences:  41%|████▏     | 166/401 [1:01:03<1:26:20, 22.05s/it]
#
# Sampling chain 0, 0 divergences:  42%|████▏     | 167/401 [1:01:25<1:26:28, 22.17s/it]
#
# Sampling chain 0, 0 divergences:  42%|████▏     | 168/401 [1:01:47<1:26:03, 22.16s/it]
#
# Sampling chain 0, 0 divergences:  42%|████▏     | 169/401 [1:02:09<1:25:31, 22.12s/it]
#
# Sampling chain 0, 0 divergences:  42%|████▏     | 170/401 [1:02:31<1:25:06, 22.11s/it]
#
# Sampling chain 0, 0 divergences:  43%|████▎     | 171/401 [1:02:53<1:24:05, 21.94s/it]
#
# Sampling chain 0, 0 divergences:  43%|████▎     | 172/401 [1:03:15<1:24:08, 22.04s/it]
#
# Sampling chain 0, 0 divergences:  43%|████▎     | 173/401 [1:03:37<1:23:51, 22.07s/it]
#
# Sampling chain 0, 0 divergences:  43%|████▎     | 174/401 [1:04:00<1:23:47, 22.15s/it]
# Sampling chain 0, 0 divergences:  44%|████▎     | 175/401 [1:04:22<1:23:08, 22.07s/it]
#
# Sampling chain 0, 0 divergences:  44%|████▍     | 176/401 [1:04:44<1:23:25, 22.25s/it]
#
# Sampling chain 0, 0 divergences:  44%|████▍     | 177/401 [1:05:07<1:23:12, 22.29s/it]
#
# Sampling chain 0, 0 divergences:  44%|████▍     | 178/401 [1:05:28<1:21:58, 22.05s/it]
#
# Sampling chain 0, 0 divergences:  45%|████▍     | 179/401 [1:05:51<1:22:03, 22.18s/it]
#
# Sampling chain 0, 0 divergences:  45%|████▍     | 180/401 [1:06:13<1:21:53, 22.24s/it]
#
# Sampling chain 0, 0 divergences:  45%|████▌     | 181/401 [1:06:35<1:21:42, 22.28s/it]
#
# Sampling chain 0, 0 divergences:  45%|████▌     | 182/401 [1:06:57<1:21:11, 22.25s/it]
#
# Sampling chain 0, 0 divergences:  46%|████▌     | 183/401 [1:07:20<1:21:05, 22.32s/it]
#
# Sampling chain 0, 0 divergences:  46%|████▌     | 184/401 [1:07:42<1:20:20, 22.21s/it]
#
# Sampling chain 0, 0 divergences:  46%|████▌     | 185/401 [1:08:04<1:19:20, 22.04s/it]
#
# Sampling chain 0, 0 divergences:  46%|████▋     | 186/401 [1:08:25<1:18:18, 21.85s/it]
#
# Sampling chain 0, 0 divergences:  47%|████▋     | 187/401 [1:08:47<1:18:15, 21.94s/it]
#
# Sampling chain 0, 0 divergences:  47%|████▋     | 188/401 [1:09:10<1:18:22, 22.08s/it]
#
# Sampling chain 0, 0 divergences:  47%|████▋     | 189/401 [1:09:32<1:17:57, 22.06s/it]
#
# Sampling chain 0, 0 divergences:  47%|████▋     | 190/401 [1:09:54<1:17:33, 22.05s/it]
#
# Sampling chain 0, 0 divergences:  48%|████▊     | 191/401 [1:10:16<1:17:42, 22.20s/it]
#
# Sampling chain 0, 0 divergences:  48%|████▊     | 192/401 [1:10:39<1:18:00, 22.40s/it]
#
# Sampling chain 0, 0 divergences:  48%|████▊     | 193/401 [1:11:01<1:17:36, 22.39s/it]
#
# Sampling chain 0, 0 divergences:  48%|████▊     | 194/401 [1:11:23<1:16:50, 22.27s/it]
#
# Sampling chain 0, 0 divergences:  49%|████▊     | 195/401 [1:11:45<1:16:03, 22.15s/it]
#
# Sampling chain 0, 0 divergences:  49%|████▉     | 196/401 [1:12:07<1:15:36, 22.13s/it]
#
# Sampling chain 0, 0 divergences:  49%|████▉     | 197/401 [1:12:29<1:15:04, 22.08s/it]
#
# Sampling chain 0, 0 divergences:  49%|████▉     | 198/401 [1:12:51<1:14:01, 21.88s/it]
#
# Sampling chain 0, 0 divergences:  50%|████▉     | 199/401 [1:13:13<1:13:45, 21.91s/it]
#
# Sampling chain 0, 0 divergences:  50%|████▉     | 200/401 [1:13:35<1:13:57, 22.08s/it]
#
# Sampling chain 0, 0 divergences:  50%|█████     | 201/401 [1:13:58<1:13:56, 22.18s/it]
#
# Sampling chain 0, 0 divergences:  50%|█████     | 202/401 [1:14:19<1:12:57, 22.00s/it]
#
# Sampling chain 0, 0 divergences:  51%|█████     | 203/401 [1:14:41<1:12:52, 22.08s/it]
#
# Sampling chain 0, 0 divergences:  51%|█████     | 204/401 [1:15:03<1:12:26, 22.07s/it]
#
# Sampling chain 0, 0 divergences:  51%|█████     | 205/401 [1:15:26<1:12:12, 22.10s/it]
#
# Sampling chain 0, 0 divergences:  51%|█████▏    | 206/401 [1:15:48<1:12:01, 22.16s/it]
#
# Sampling chain 0, 0 divergences:  52%|█████▏    | 207/401 [1:16:10<1:11:23, 22.08s/it]
#
# Sampling chain 0, 0 divergences:  52%|█████▏    | 208/401 [1:16:32<1:10:54, 22.04s/it]
#
# Sampling chain 0, 0 divergences:  52%|█████▏    | 209/401 [1:16:54<1:10:55, 22.16s/it]
#
# Sampling chain 0, 0 divergences:  52%|█████▏    | 210/401 [1:17:17<1:10:49, 22.25s/it]
#
# Sampling chain 0, 0 divergences:  53%|█████▎    | 211/401 [1:17:39<1:10:34, 22.29s/it]
#
# Sampling chain 0, 0 divergences:  53%|█████▎    | 212/401 [1:18:01<1:09:54, 22.20s/it]
#
# Sampling chain 0, 0 divergences:  53%|█████▎    | 213/401 [1:18:23<1:09:38, 22.23s/it]
#
# Sampling chain 0, 0 divergences:  53%|█████▎    | 214/401 [1:18:45<1:09:00, 22.14s/it]
#
# Sampling chain 0, 0 divergences:  54%|█████▎    | 215/401 [1:19:07<1:08:36, 22.13s/it]
#
# Sampling chain 0, 0 divergences:  54%|█████▍    | 216/401 [1:19:29<1:07:31, 21.90s/it]
#
# Sampling chain 0, 0 divergences:  54%|█████▍    | 217/401 [1:19:51<1:07:10, 21.90s/it]
#
# Sampling chain 0, 0 divergences:  54%|█████▍    | 218/401 [1:20:13<1:06:53, 21.93s/it]
#
# Sampling chain 0, 0 divergences:  55%|█████▍    | 219/401 [1:20:34<1:06:25, 21.90s/it]
#
# Sampling chain 0, 0 divergences:  55%|█████▍    | 220/401 [1:20:56<1:05:53, 21.84s/it]
#
# Sampling chain 0, 0 divergences:  55%|█████▌    | 221/401 [1:21:18<1:05:39, 21.89s/it]
#
# Sampling chain 0, 0 divergences:  55%|█████▌    | 222/401 [1:21:41<1:05:44, 22.04s/it]
#
# Sampling chain 0, 0 divergences:  56%|█████▌    | 223/401 [1:22:02<1:04:51, 21.86s/it]
#
# Sampling chain 0, 0 divergences:  56%|█████▌    | 224/401 [1:22:24<1:05:03, 22.05s/it]
#
# Sampling chain 0, 0 divergences:  56%|█████▌    | 225/401 [1:22:47<1:04:55, 22.14s/it]
#
# Sampling chain 0, 0 divergences:  56%|█████▋    | 226/401 [1:23:08<1:04:02, 21.96s/it]
#
# Sampling chain 0, 0 divergences:  57%|█████▋    | 227/401 [1:23:30<1:03:42, 21.97s/it]
#
# Sampling chain 0, 0 divergences:  57%|█████▋    | 228/401 [1:23:53<1:03:56, 22.18s/it]
#
# Sampling chain 0, 0 divergences:  57%|█████▋    | 229/401 [1:24:15<1:03:39, 22.21s/it]
#
# Sampling chain 0, 0 divergences:  57%|█████▋    | 230/401 [1:24:38<1:03:24, 22.25s/it]
#
# Sampling chain 0, 0 divergences:  58%|█████▊    | 231/401 [1:24:59<1:02:31, 22.07s/it]
#
# Sampling chain 0, 0 divergences:  58%|█████▊    | 232/401 [1:25:22<1:02:39, 22.24s/it]
#
# Sampling chain 0, 0 divergences:  58%|█████▊    | 233/401 [1:25:44<1:02:19, 22.26s/it]
#
# Sampling chain 0, 0 divergences:  58%|█████▊    | 234/401 [1:26:06<1:01:40, 22.16s/it]
#
# Sampling chain 0, 0 divergences:  59%|█████▊    | 235/401 [1:26:28<1:01:06, 22.09s/it]
#
# Sampling chain 0, 0 divergences:  59%|█████▉    | 236/401 [1:26:51<1:01:03, 22.20s/it]
#
# Sampling chain 0, 0 divergences:  59%|█████▉    | 237/401 [1:27:13<1:00:56, 22.30s/it]
#
# Sampling chain 0, 0 divergences:  59%|█████▉    | 238/401 [1:27:34<59:51, 22.03s/it]
#
# Sampling chain 0, 0 divergences:  60%|█████▉    | 239/401 [1:27:57<59:47, 22.14s/it]
#
# Sampling chain 0, 0 divergences:  60%|█████▉    | 240/401 [1:28:19<59:08, 22.04s/it]
#
# Sampling chain 0, 0 divergences:  60%|██████    | 241/401 [1:28:40<58:29, 21.94s/it]
#
# Sampling chain 0, 0 divergences:  60%|██████    | 242/401 [1:29:02<58:07, 21.94s/it]
#
# Sampling chain 0, 0 divergences:  61%|██████    | 243/401 [1:29:24<57:45, 21.93s/it]
#
# Sampling chain 0, 0 divergences:  61%|██████    | 244/401 [1:29:46<57:06, 21.82s/it]
#
# Sampling chain 0, 0 divergences:  61%|██████    | 245/401 [1:30:08<56:56, 21.90s/it]
#
# Sampling chain 0, 0 divergences:  61%|██████▏   | 246/401 [1:30:30<56:59, 22.06s/it]
#
# Sampling chain 0, 0 divergences:  62%|██████▏   | 247/401 [1:30:52<56:31, 22.02s/it]
#
# Sampling chain 0, 0 divergences:  62%|██████▏   | 248/401 [1:31:14<56:08, 22.02s/it]
#
# Sampling chain 0, 0 divergences:  62%|██████▏   | 249/401 [1:31:37<55:57, 22.09s/it]
#
# Sampling chain 0, 0 divergences:  62%|██████▏   | 250/401 [1:31:59<55:53, 22.21s/it]
#
# Sampling chain 0, 0 divergences:  63%|██████▎   | 251/401 [1:32:21<55:19, 22.13s/it]
#
# Sampling chain 0, 0 divergences:  63%|██████▎   | 252/401 [1:32:42<54:27, 21.93s/it]
#
# Sampling chain 0, 0 divergences:  63%|██████▎   | 253/401 [1:33:05<54:23, 22.05s/it]
#
# Sampling chain 0, 0 divergences:  63%|██████▎   | 254/401 [1:33:26<53:38, 21.90s/it]
#
# Sampling chain 0, 0 divergences:  64%|██████▎   | 255/401 [1:33:48<53:15, 21.89s/it]
#
# Sampling chain 0, 0 divergences:  64%|██████▍   | 256/401 [1:34:11<53:21, 22.08s/it]
#
# Sampling chain 0, 0 divergences:  64%|██████▍   | 257/401 [1:34:32<52:35, 21.91s/it]
#
# Sampling chain 0, 0 divergences:  64%|██████▍   | 258/401 [1:34:54<52:06, 21.86s/it]
#
# Sampling chain 0, 0 divergences:  65%|██████▍   | 259/401 [1:35:15<51:22, 21.71s/it]
#
# Sampling chain 0, 0 divergences:  65%|██████▍   | 260/401 [1:35:37<51:06, 21.75s/it]
#
# Sampling chain 0, 0 divergences:  65%|██████▌   | 261/401 [1:35:59<50:33, 21.67s/it]
#
# Sampling chain 0, 0 divergences:  65%|██████▌   | 262/401 [1:36:21<50:33, 21.82s/it]
#
# Sampling chain 0, 0 divergences:  66%|██████▌   | 263/401 [1:36:43<50:17, 21.87s/it]
#
# Sampling chain 0, 0 divergences:  66%|██████▌   | 264/401 [1:37:05<50:05, 21.94s/it]
#
# Sampling chain 0, 0 divergences:  66%|██████▌   | 265/401 [1:37:27<49:42, 21.93s/it]
#
# Sampling chain 0, 0 divergences:  66%|██████▋   | 266/401 [1:37:49<49:14, 21.89s/it]
#
# Sampling chain 0, 0 divergences:  67%|██████▋   | 267/401 [1:38:10<48:40, 21.79s/it]
#
# Sampling chain 0, 0 divergences:  67%|██████▋   | 268/401 [1:38:32<48:15, 21.77s/it]
#
# Sampling chain 0, 0 divergences:  67%|██████▋   | 269/401 [1:38:54<47:55, 21.78s/it]
#
# Sampling chain 0, 0 divergences:  67%|██████▋   | 270/401 [1:39:16<47:42, 21.85s/it]
#
# Sampling chain 0, 0 divergences:  68%|██████▊   | 271/401 [1:39:38<47:27, 21.90s/it]
#
# Sampling chain 0, 0 divergences:  68%|██████▊   | 272/401 [1:40:00<47:05, 21.90s/it]
#
# Sampling chain 0, 0 divergences:  68%|██████▊   | 273/401 [1:40:22<47:06, 22.09s/it]
#
# Sampling chain 0, 0 divergences:  68%|██████▊   | 274/401 [1:40:44<46:39, 22.05s/it]
#
# Sampling chain 0, 0 divergences:  69%|██████▊   | 275/401 [1:41:06<46:22, 22.09s/it]
#
# Sampling chain 0, 0 divergences:  69%|██████▉   | 276/401 [5:41:42<150:54:41, 4346.25s/it]
#
# Sampling chain 0, 0 divergences:  69%|██████▉   | 277/401 [9:42:16<253:56:15, 7372.38s/it]
#
# Sampling chain 0, 0 divergences:  69%|██████▉   | 278/401 [11:25:00<239:30:35, 7010.04s/it]
#
# Sampling chain 0, 0 divergences:  70%|██████▉   | 279/401 [11:25:25<166:32:32, 4914.37s/it]
#
# Sampling chain 0, 0 divergences:  70%|██████▉   | 280/401 [11:25:48<115:51:19, 3446.94s/it]
#
# Sampling chain 0, 0 divergences:  70%|███████   | 281/401 [11:26:11<80:39:47, 2419.90s/it]
#
# Sampling chain 0, 0 divergences:  70%|███████   | 282/401 [11:26:34<56:13:19, 1700.84s/it]
#
# Sampling chain 0, 0 divergences:  71%|███████   | 283/401 [11:26:57<39:15:05, 1197.50s/it]
#
# Sampling chain 0, 0 divergences:  71%|███████   | 284/401 [11:27:21<27:28:25, 845.35s/it]
#
# Sampling chain 0, 0 divergences:  71%|███████   | 285/401 [11:27:45<19:18:03, 598.99s/it]
#
# Sampling chain 0, 0 divergences:  71%|███████▏  | 286/401 [11:28:08<13:36:56, 426.23s/it]
#
# Sampling chain 0, 0 divergences:  72%|███████▏  | 287/401 [11:28:31<9:39:42, 305.11s/it]
#
# Sampling chain 0, 0 divergences:  72%|███████▏  | 288/401 [11:28:53<6:54:58, 220.34s/it]
#
# Sampling chain 0, 0 divergences:  72%|███████▏  | 289/401 [11:29:16<5:00:55, 161.21s/it]
#
# Sampling chain 0, 0 divergences:  72%|███████▏  | 290/401 [11:29:39<3:41:35, 119.78s/it]
#
# Sampling chain 0, 0 divergences:  73%|███████▎  | 291/401 [11:30:02<2:46:18, 90.71s/it]
#
# Sampling chain 0, 0 divergences:  73%|███████▎  | 292/401 [11:30:25<2:07:29, 70.18s/it]
#
# Sampling chain 0, 0 divergences:  73%|███████▎  | 293/401 [11:30:48<1:40:54, 56.06s/it]
#
# Sampling chain 0, 0 divergences:  73%|███████▎  | 294/401 [11:31:10<1:22:07, 46.05s/it]
#
# Sampling chain 0, 0 divergences:  74%|███████▎  | 295/401 [11:31:33<1:08:45, 38.92s/it]
#
# Sampling chain 0, 0 divergences:  74%|███████▍  | 296/401 [11:31:56<59:48, 34.17s/it]
#
# Sampling chain 0, 0 divergences:  74%|███████▍  | 297/401 [11:32:18<53:12, 30.70s/it]
#
# Sampling chain 0, 0 divergences:  74%|███████▍  | 298/401 [11:32:41<48:41, 28.37s/it]
#
# Sampling chain 0, 0 divergences:  75%|███████▍  | 299/401 [11:33:05<45:47, 26.94s/it]
#
# Sampling chain 0, 0 divergences:  75%|███████▍  | 300/401 [11:33:28<43:33, 25.88s/it]
#
# Sampling chain 0, 0 divergences:  75%|███████▌  | 301/401 [11:33:51<41:20, 24.81s/it]
#
# Sampling chain 0, 0 divergences:  75%|███████▌  | 302/401 [11:34:14<40:06, 24.30s/it]
#
# Sampling chain 0, 0 divergences:  76%|███████▌  | 303/401 [11:34:37<39:06, 23.94s/it]
#
# Sampling chain 0, 0 divergences:  76%|███████▌  | 304/401 [11:35:02<39:08, 24.21s/it]
#
# Sampling chain 0, 0 divergences:  76%|███████▌  | 305/401 [11:35:27<39:09, 24.47s/it]
#
# Sampling chain 0, 0 divergences:  76%|███████▋  | 306/401 [11:35:51<38:38, 24.40s/it]
#
# Sampling chain 0, 0 divergences:  77%|███████▋  | 307/401 [11:36:14<37:36, 24.00s/it]
#
# Sampling chain 0, 0 divergences:  77%|███████▋  | 308/401 [11:36:37<36:37, 23.63s/it]
#
# Sampling chain 0, 0 divergences:  77%|███████▋  | 309/401 [11:37:00<35:58, 23.46s/it]
#
# Sampling chain 0, 0 divergences:  77%|███████▋  | 310/401 [11:37:23<35:23, 23.33s/it]
#
# Sampling chain 0, 0 divergences:  78%|███████▊  | 311/401 [11:37:46<35:03, 23.37s/it]
#
# Sampling chain 0, 0 divergences:  78%|███████▊  | 312/401 [11:38:10<34:39, 23.37s/it]
#
# Sampling chain 0, 0 divergences:  78%|███████▊  | 313/401 [11:38:33<34:23, 23.44s/it]
#
# Sampling chain 0, 0 divergences:  78%|███████▊  | 314/401 [11:38:56<33:43, 23.25s/it]
#
# Sampling chain 0, 0 divergences:  79%|███████▊  | 315/401 [11:39:19<33:07, 23.11s/it]
#
# Sampling chain 0, 0 divergences:  79%|███████▉  | 316/401 [11:39:41<32:29, 22.94s/it]
#
# Sampling chain 0, 0 divergences:  79%|███████▉  | 317/401 [11:40:04<32:05, 22.93s/it]
#
# Sampling chain 0, 0 divergences:  79%|███████▉  | 318/401 [11:40:27<31:37, 22.86s/it]
#
# Sampling chain 0, 0 divergences:  80%|███████▉  | 319/401 [11:40:50<31:18, 22.91s/it]
#
# Sampling chain 0, 0 divergences:  80%|███████▉  | 320/401 [11:41:12<30:31, 22.62s/it]
#
# Sampling chain 0, 0 divergences:  80%|████████  | 321/401 [11:41:35<30:11, 22.65s/it]
#
# Sampling chain 0, 0 divergences:  80%|████████  | 322/401 [11:41:58<29:54, 22.71s/it]
#
# Sampling chain 0, 0 divergences:  81%|████████  | 323/401 [11:42:21<29:41, 22.85s/it]
#
# Sampling chain 0, 0 divergences:  81%|████████  | 324/401 [11:42:46<30:03, 23.43s/it]
#
# Sampling chain 0, 0 divergences:  81%|████████  | 325/401 [11:43:10<29:52, 23.59s/it]
#
# Sampling chain 0, 0 divergences:  81%|████████▏ | 326/401 [11:43:32<28:59, 23.20s/it]
#
# Sampling chain 0, 0 divergences:  82%|████████▏ | 327/401 [11:43:54<28:16, 22.92s/it]
#
# Sampling chain 0, 0 divergences:  82%|████████▏ | 328/401 [11:44:16<27:40, 22.75s/it]
#
# Sampling chain 0, 0 divergences:  82%|████████▏ | 329/401 [11:44:38<26:57, 22.47s/it]
#
# Sampling chain 0, 0 divergences:  82%|████████▏ | 330/401 [11:45:01<26:36, 22.49s/it]
#
# Sampling chain 0, 0 divergences:  83%|████████▎ | 331/401 [11:45:23<26:14, 22.50s/it]
#
# Sampling chain 0, 0 divergences:  83%|████████▎ | 332/401 [11:45:50<27:21, 23.79s/it]
#
# Sampling chain 0, 0 divergences:  83%|████████▎ | 333/401 [11:46:13<26:41, 23.55s/it]
#
# Sampling chain 0, 0 divergences:  83%|████████▎ | 334/401 [11:46:36<25:54, 23.20s/it]
#
# Sampling chain 0, 0 divergences:  84%|████████▎ | 335/401 [11:46:59<25:28, 23.15s/it]
#
# Sampling chain 0, 0 divergences:  84%|████████▍ | 336/401 [11:47:22<25:16, 23.33s/it]
#
# Sampling chain 0, 0 divergences:  84%|████████▍ | 337/401 [11:47:45<24:44, 23.19s/it]
#
# Sampling chain 0, 0 divergences:  84%|████████▍ | 338/401 [11:48:10<24:44, 23.56s/it]
#
# Sampling chain 0, 0 divergences:  85%|████████▍ | 339/401 [11:48:33<24:19, 23.55s/it]
#
# Sampling chain 0, 0 divergences:  85%|████████▍ | 340/401 [11:48:57<24:00, 23.62s/it]
#
# Sampling chain 0, 0 divergences:  85%|████████▌ | 341/401 [11:49:19<23:18, 23.30s/it]
#
# Sampling chain 0, 0 divergences:  85%|████████▌ | 342/401 [11:49:43<22:55, 23.31s/it]
#
# Sampling chain 0, 0 divergences:  86%|████████▌ | 343/401 [11:50:07<22:53, 23.69s/it]
#
# Sampling chain 0, 0 divergences:  86%|████████▌ | 344/401 [11:50:31<22:34, 23.76s/it]
#
# Sampling chain 0, 0 divergences:  86%|████████▌ | 345/401 [11:50:56<22:19, 23.93s/it]
#
# Sampling chain 0, 0 divergences:  86%|████████▋ | 346/401 [11:51:19<21:45, 23.74s/it]
#
# Sampling chain 0, 0 divergences:  87%|████████▋ | 347/401 [11:51:42<21:14, 23.59s/it]
#
# Sampling chain 0, 0 divergences:  87%|████████▋ | 348/401 [11:52:06<20:49, 23.58s/it]
# Sampling chain 0, 0 divergences:  87%|████████▋ | 349/401 [11:52:29<20:25, 23.57s/it]
#
# Sampling chain 0, 0 divergences:  87%|████████▋ | 350/401 [11:52:52<19:53, 23.41s/it]
#
# Sampling chain 0, 0 divergences:  88%|████████▊ | 351/401 [11:53:16<19:33, 23.47s/it]
#
# Sampling chain 0, 0 divergences:  88%|████████▊ | 352/401 [11:53:39<19:10, 23.49s/it]
#
# Sampling chain 0, 0 divergences:  88%|████████▊ | 353/401 [11:54:03<18:41, 23.37s/it]
#
# Sampling chain 0, 0 divergences:  88%|████████▊ | 354/401 [11:54:25<18:10, 23.21s/it]
#
# Sampling chain 0, 0 divergences:  89%|████████▊ | 355/401 [11:54:49<17:52, 23.32s/it]
#
# Sampling chain 0, 0 divergences:  89%|████████▉ | 356/401 [11:55:12<17:30, 23.34s/it]
#
# Sampling chain 0, 0 divergences:  89%|████████▉ | 357/401 [11:55:36<17:07, 23.35s/it]
#
# Sampling chain 0, 0 divergences:  89%|████████▉ | 358/401 [11:55:58<16:35, 23.16s/it]
#
# Sampling chain 0, 0 divergences:  90%|████████▉ | 359/401 [11:56:22<16:12, 23.14s/it]
#
# Sampling chain 0, 0 divergences:  90%|████████▉ | 360/401 [11:56:45<15:52, 23.22s/it]
#
# Sampling chain 0, 0 divergences:  90%|█████████ | 361/401 [11:57:09<15:37, 23.44s/it]
#
# Sampling chain 0, 0 divergences:  90%|█████████ | 362/401 [11:57:32<15:12, 23.40s/it]
#
# Sampling chain 0, 0 divergences:  91%|█████████ | 363/401 [11:57:55<14:48, 23.37s/it]
#
# Sampling chain 0, 0 divergences:  91%|█████████ | 364/401 [11:58:19<14:23, 23.33s/it]
#
# Sampling chain 0, 0 divergences:  91%|█████████ | 365/401 [11:58:41<13:52, 23.14s/it]
#
# Sampling chain 0, 0 divergences:  91%|█████████▏| 366/401 [11:59:05<13:32, 23.22s/it]
#
# Sampling chain 0, 0 divergences:  92%|█████████▏| 367/401 [11:59:28<13:13, 23.34s/it]
#
# Sampling chain 0, 0 divergences:  92%|█████████▏| 368/401 [11:59:51<12:46, 23.22s/it]
#
# Sampling chain 0, 0 divergences:  92%|█████████▏| 369/401 [12:00:14<12:22, 23.19s/it]
#
# Sampling chain 0, 0 divergences:  92%|█████████▏| 370/401 [12:00:37<11:52, 22.98s/it]
#
# Sampling chain 0, 0 divergences:  93%|█████████▎| 371/401 [12:01:00<11:31, 23.04s/it]
#
# Sampling chain 0, 0 divergences:  93%|█████████▎| 372/401 [12:01:24<11:19, 23.42s/it]
#
# Sampling chain 0, 0 divergences:  93%|█████████▎| 373/401 [12:01:48<10:58, 23.53s/it]
#
# Sampling chain 0, 0 divergences:  93%|█████████▎| 374/401 [12:02:13<10:43, 23.84s/it]
#
# Sampling chain 0, 0 divergences:  94%|█████████▎| 375/401 [12:02:38<10:27, 24.13s/it]
#
# Sampling chain 0, 0 divergences:  94%|█████████▍| 376/401 [12:03:01<09:53, 23.75s/it]
#
# Sampling chain 0, 0 divergences:  94%|█████████▍| 377/401 [12:03:24<09:29, 23.72s/it]
#
# Sampling chain 0, 0 divergences:  94%|█████████▍| 378/401 [12:03:47<08:58, 23.41s/it]
#
# Sampling chain 0, 0 divergences:  95%|█████████▍| 379/401 [12:04:10<08:34, 23.38s/it]
#
# Sampling chain 0, 0 divergences:  95%|█████████▍| 380/401 [12:04:34<08:13, 23.51s/it]
#
# Sampling chain 0, 0 divergences:  95%|█████████▌| 381/401 [12:04:58<07:52, 23.63s/it]
#
# Sampling chain 0, 0 divergences:  95%|█████████▌| 382/401 [12:05:21<07:24, 23.37s/it]
#
# Sampling chain 0, 0 divergences:  96%|█████████▌| 383/401 [12:05:44<06:59, 23.32s/it]
#
# Sampling chain 0, 0 divergences:  96%|█████████▌| 384/401 [12:06:07<06:36, 23.35s/it]
#
# Sampling chain 0, 0 divergences:  96%|█████████▌| 385/401 [12:06:30<06:12, 23.26s/it]
#
# Sampling chain 0, 0 divergences:  96%|█████████▋| 386/401 [12:06:53<05:47, 23.19s/it]
#
# Sampling chain 0, 0 divergences:  97%|█████████▋| 387/401 [12:07:17<05:25, 23.26s/it]
#
# Sampling chain 0, 0 divergences:  97%|█████████▋| 388/401 [12:07:41<05:04, 23.46s/it]
#
# Sampling chain 0, 0 divergences:  97%|█████████▋| 389/401 [12:08:04<04:39, 23.28s/it]
#
# Sampling chain 0, 0 divergences:  97%|█████████▋| 390/401 [12:08:27<04:16, 23.35s/it]
#
# Sampling chain 0, 0 divergences:  98%|█████████▊| 391/401 [12:08:50<03:52, 23.25s/it]
#
# Sampling chain 0, 0 divergences:  98%|█████████▊| 392/401 [12:09:13<03:28, 23.13s/it]
#
# Sampling chain 0, 0 divergences:  98%|█████████▊| 393/401 [12:09:36<03:03, 22.96s/it]
#
# Sampling chain 0, 0 divergences:  98%|█████████▊| 394/401 [12:09:59<02:41, 23.08s/it]
#
# Sampling chain 0, 0 divergences:  99%|█████████▊| 395/401 [12:10:22<02:17, 22.98s/it]
#
# Sampling chain 0, 0 divergences:  99%|█████████▉| 396/401 [12:10:45<01:54, 22.98s/it]
#
# Sampling chain 0, 0 divergences:  99%|█████████▉| 397/401 [12:11:07<01:31, 22.96s/it]
#
# Sampling chain 0, 0 divergences:  99%|█████████▉| 398/401 [12:11:31<01:08, 22.98s/it]
#
# Sampling chain 0, 0 divergences: 100%|█████████▉| 399/401 [12:11:54<00:45, 22.99s/it]
#
# Sampling chain 0, 0 divergences: 100%|█████████▉| 400/401 [12:12:17<00:23, 23.14s/it]
#
# Sampling chain 0, 0 divergences: 100%|██████████| 401/401 [12:12:41<00:00, 23.27s/it]
#
#
#
# Sampling chain 1, 0 divergences:   0%|          | 0/401 [00:00<?, ?it/s]
#
# Sampling chain 1, 0 divergences:   0%|          | 1/401 [00:22<2:32:01, 22.80s/it]
#
# Sampling chain 1, 0 divergences:   0%|          | 2/401 [00:45<2:31:50, 22.83s/it]
#
# Sampling chain 1, 0 divergences:   1%|          | 3/401 [01:09<2:32:38, 23.01s/it]
#
# Sampling chain 1, 0 divergences:   1%|          | 4/401 [01:32<2:32:04, 22.98s/it]
#
# Sampling chain 1, 0 divergences:   1%|          | 5/401 [01:54<2:31:33, 22.96s/it]
#
# Sampling chain 1, 0 divergences:   1%|▏         | 6/401 [02:17<2:31:02, 22.94s/it]
#
# Sampling chain 1, 0 divergences:   2%|▏         | 7/401 [02:40<2:30:46, 22.96s/it]
#
# Sampling chain 1, 0 divergences:   2%|▏         | 8/401 [03:03<2:30:19, 22.95s/it]
#
# Sampling chain 1, 0 divergences:   2%|▏         | 9/401 [03:26<2:30:15, 23.00s/it]
#
# Sampling chain 1, 0 divergences:   2%|▏         | 10/401 [03:49<2:29:51, 23.00s/it]
#
# Sampling chain 1, 0 divergences:   3%|▎         | 11/401 [04:12<2:29:18, 22.97s/it]
#
# Sampling chain 1, 0 divergences:   3%|▎         | 12/401 [04:35<2:28:51, 22.96s/it]
#
# Sampling chain 1, 0 divergences:   3%|▎         | 13/401 [04:58<2:27:29, 22.81s/it]
#
# Sampling chain 1, 0 divergences:   3%|▎         | 14/401 [05:21<2:27:10, 22.82s/it]
#
# Sampling chain 1, 0 divergences:   4%|▎         | 15/401 [05:44<2:27:45, 22.97s/it]
#
# Sampling chain 1, 0 divergences:   4%|▍         | 16/401 [06:07<2:28:14, 23.10s/it]
#
# Sampling chain 1, 0 divergences:   4%|▍         | 17/401 [06:30<2:27:42, 23.08s/it]
#
# Sampling chain 1, 0 divergences:   4%|▍         | 18/401 [06:54<2:28:15, 23.23s/it]
#
# Sampling chain 1, 0 divergences:   5%|▍         | 19/401 [07:17<2:27:46, 23.21s/it]
#
# Sampling chain 1, 0 divergences:   5%|▍         | 20/401 [07:40<2:27:13, 23.18s/it]
#
# Sampling chain 1, 0 divergences:   5%|▌         | 21/401 [08:03<2:26:43, 23.17s/it]
#
# Sampling chain 1, 0 divergences:   5%|▌         | 22/401 [08:27<2:27:48, 23.40s/it]
#
# Sampling chain 1, 0 divergences:   6%|▌         | 23/401 [08:52<2:29:06, 23.67s/it]
#
# Sampling chain 1, 0 divergences:   6%|▌         | 24/401 [09:16<2:30:11, 23.90s/it]
#
# Sampling chain 1, 0 divergences:   6%|▌         | 25/401 [09:40<2:29:50, 23.91s/it]
#
# Sampling chain 1, 0 divergences:   6%|▋         | 26/401 [10:03<2:27:40, 23.63s/it]
#
# Sampling chain 1, 0 divergences:   7%|▋         | 27/401 [10:26<2:27:00, 23.59s/it]
#
# Sampling chain 1, 0 divergences:   7%|▋         | 28/401 [10:50<2:26:57, 23.64s/it]
#
# Sampling chain 1, 0 divergences:   7%|▋         | 29/401 [11:14<2:26:36, 23.65s/it]
#
# Sampling chain 1, 0 divergences:   7%|▋         | 30/401 [11:37<2:25:53, 23.60s/it]
#
# Sampling chain 1, 0 divergences:   8%|▊         | 31/401 [12:01<2:24:58, 23.51s/it]
#
# Sampling chain 1, 0 divergences:   8%|▊         | 32/401 [12:25<2:25:23, 23.64s/it]
#
# Sampling chain 1, 0 divergences:   8%|▊         | 33/401 [12:48<2:24:22, 23.54s/it]
#
# Sampling chain 1, 0 divergences:   8%|▊         | 34/401 [13:12<2:24:13, 23.58s/it]
#
# Sampling chain 1, 0 divergences:   9%|▊         | 35/401 [13:35<2:23:26, 23.51s/it]
# Sampling chain 1, 0 divergences:   9%|▉         | 36/401 [13:58<2:21:28, 23.26s/it]
#
# Sampling chain 1, 0 divergences:   9%|▉         | 37/401 [14:21<2:21:27, 23.32s/it]
#
# Sampling chain 1, 0 divergences:   9%|▉         | 38/401 [14:45<2:21:38, 23.41s/it]
#
# Sampling chain 1, 0 divergences:  10%|▉         | 39/401 [15:08<2:21:43, 23.49s/it]
#
# Sampling chain 1, 0 divergences:  10%|▉         | 40/401 [15:32<2:21:41, 23.55s/it]
#
# Sampling chain 1, 0 divergences:  10%|█         | 41/401 [15:55<2:20:46, 23.46s/it]
#
# Sampling chain 1, 0 divergences:  10%|█         | 42/401 [16:19<2:20:54, 23.55s/it]
#
# Sampling chain 1, 0 divergences:  11%|█         | 43/401 [16:42<2:19:09, 23.32s/it]
#
# Sampling chain 1, 0 divergences:  11%|█         | 44/401 [17:05<2:18:52, 23.34s/it]
#
# Sampling chain 1, 0 divergences:  11%|█         | 45/401 [17:29<2:18:46, 23.39s/it]
#
# Sampling chain 1, 0 divergences:  11%|█▏        | 46/401 [17:52<2:18:43, 23.45s/it]
#
# Sampling chain 1, 0 divergences:  12%|█▏        | 47/401 [18:15<2:17:46, 23.35s/it]
#
# Sampling chain 1, 0 divergences:  12%|█▏        | 48/401 [18:38<2:16:38, 23.22s/it]
#
# Sampling chain 1, 0 divergences:  12%|█▏        | 49/401 [19:02<2:16:14, 23.22s/it]
#
# Sampling chain 1, 0 divergences:  12%|█▏        | 50/401 [19:25<2:15:42, 23.20s/it]
#
# Sampling chain 1, 0 divergences:  13%|█▎        | 51/401 [19:48<2:15:59, 23.31s/it]
#
# Sampling chain 1, 0 divergences:  13%|█▎        | 52/401 [20:11<2:15:00, 23.21s/it]
#
# Sampling chain 1, 0 divergences:  13%|█▎        | 53/401 [20:35<2:15:22, 23.34s/it]
#
# Sampling chain 1, 0 divergences:  13%|█▎        | 54/401 [20:58<2:15:27, 23.42s/it]
#
# Sampling chain 1, 0 divergences:  14%|█▎        | 55/401 [21:22<2:14:28, 23.32s/it]
#
# Sampling chain 1, 0 divergences:  14%|█▍        | 56/401 [21:44<2:12:56, 23.12s/it]
#
# Sampling chain 1, 0 divergences:  14%|█▍        | 57/401 [22:08<2:13:27, 23.28s/it]
#
# Sampling chain 1, 0 divergences:  14%|█▍        | 58/401 [22:31<2:13:32, 23.36s/it]
#
# Sampling chain 1, 0 divergences:  15%|█▍        | 59/401 [22:54<2:12:33, 23.25s/it]
#
# Sampling chain 1, 0 divergences:  15%|█▍        | 60/401 [23:17<2:11:33, 23.15s/it]
#
# Sampling chain 1, 0 divergences:  15%|█▌        | 61/401 [23:41<2:11:17, 23.17s/it]
#
# Sampling chain 1, 0 divergences:  15%|█▌        | 62/401 [24:04<2:11:10, 23.22s/it]
#
# Sampling chain 1, 0 divergences:  16%|█▌        | 63/401 [24:27<2:10:53, 23.23s/it]
#
# Sampling chain 1, 0 divergences:  16%|█▌        | 64/401 [24:50<2:10:37, 23.26s/it]
#
# Sampling chain 1, 0 divergences:  16%|█▌        | 65/401 [25:14<2:10:12, 23.25s/it]
#
# Sampling chain 1, 0 divergences:  16%|█▋        | 66/401 [25:37<2:09:49, 23.25s/it]
#
# Sampling chain 1, 0 divergences:  17%|█▋        | 67/401 [26:01<2:11:24, 23.61s/it]
#
# Sampling chain 1, 0 divergences:  17%|█▋        | 68/401 [26:25<2:10:37, 23.54s/it]
#
# Sampling chain 1, 0 divergences:  17%|█▋        | 69/401 [26:48<2:09:52, 23.47s/it]
#
# Sampling chain 1, 0 divergences:  17%|█▋        | 70/401 [27:12<2:10:23, 23.63s/it]
#
# Sampling chain 1, 0 divergences:  18%|█▊        | 71/401 [27:36<2:10:04, 23.65s/it]
#
# Sampling chain 1, 0 divergences:  18%|█▊        | 72/401 [27:59<2:08:52, 23.50s/it]
#
# Sampling chain 1, 0 divergences:  18%|█▊        | 73/401 [28:23<2:08:37, 23.53s/it]
#
# Sampling chain 1, 0 divergences:  18%|█▊        | 74/401 [28:46<2:08:32, 23.59s/it]
#
# Sampling chain 1, 0 divergences:  19%|█▊        | 75/401 [29:10<2:08:06, 23.58s/it]
#
# Sampling chain 1, 0 divergences:  19%|█▉        | 76/401 [29:33<2:07:02, 23.45s/it]
#
# Sampling chain 1, 0 divergences:  19%|█▉        | 77/401 [29:57<2:06:54, 23.50s/it]
#
# Sampling chain 1, 0 divergences:  19%|█▉        | 78/401 [30:20<2:06:36, 23.52s/it]
#
# Sampling chain 1, 0 divergences:  20%|█▉        | 79/401 [30:43<2:04:57, 23.28s/it]
#
# Sampling chain 1, 0 divergences:  20%|█▉        | 80/401 [31:06<2:04:25, 23.26s/it]
#
# Sampling chain 1, 0 divergences:  20%|██        | 81/401 [31:30<2:04:22, 23.32s/it]
#
# Sampling chain 1, 0 divergences:  20%|██        | 82/401 [31:53<2:03:53, 23.30s/it]
#
# Sampling chain 1, 0 divergences:  21%|██        | 83/401 [32:17<2:04:29, 23.49s/it]
#
# Sampling chain 1, 0 divergences:  21%|██        | 84/401 [32:41<2:05:36, 23.77s/it]
#
# Sampling chain 1, 0 divergences:  21%|██        | 85/401 [33:04<2:04:21, 23.61s/it]
#
# Sampling chain 1, 0 divergences:  21%|██▏       | 86/401 [33:28<2:04:33, 23.73s/it]
#
# Sampling chain 1, 0 divergences:  22%|██▏       | 87/401 [33:52<2:03:18, 23.56s/it]
#
# Sampling chain 1, 0 divergences:  22%|██▏       | 88/401 [34:15<2:02:06, 23.41s/it]
#
# Sampling chain 1, 0 divergences:  22%|██▏       | 89/401 [34:38<2:02:04, 23.47s/it]
#
# Sampling chain 1, 0 divergences:  22%|██▏       | 90/401 [35:01<2:01:05, 23.36s/it]
#
# Sampling chain 1, 0 divergences:  23%|██▎       | 91/401 [35:25<2:00:31, 23.33s/it]
#
# Sampling chain 1, 0 divergences:  23%|██▎       | 92/401 [35:47<1:59:05, 23.12s/it]
#
# Sampling chain 1, 0 divergences:  23%|██▎       | 93/401 [36:10<1:58:52, 23.16s/it]
#
# Sampling chain 1, 0 divergences:  23%|██▎       | 94/401 [36:34<1:58:48, 23.22s/it]
#
# Sampling chain 1, 0 divergences:  24%|██▎       | 95/401 [36:57<1:58:38, 23.26s/it]
#
# Sampling chain 1, 0 divergences:  24%|██▍       | 96/401 [37:21<1:58:49, 23.38s/it]
#
# Sampling chain 1, 0 divergences:  24%|██▍       | 97/401 [37:44<1:58:32, 23.40s/it]
#
# Sampling chain 1, 0 divergences:  24%|██▍       | 98/401 [38:07<1:57:28, 23.26s/it]
#
# Sampling chain 1, 0 divergences:  25%|██▍       | 99/401 [38:33<2:00:15, 23.89s/it]
#
# Sampling chain 1, 0 divergences:  25%|██▍       | 100/401 [38:57<2:00:43, 24.06s/it]
#
# Sampling chain 1, 0 divergences:  25%|██▌       | 101/401 [39:21<1:59:35, 23.92s/it]
#
# Sampling chain 1, 0 divergences:  25%|██▌       | 102/401 [39:45<1:59:51, 24.05s/it]
#
# Sampling chain 1, 0 divergences:  26%|██▌       | 103/401 [40:09<2:00:02, 24.17s/it]
#
# Sampling chain 1, 0 divergences:  26%|██▌       | 104/401 [40:33<1:58:30, 23.94s/it]
#
# Sampling chain 1, 0 divergences:  26%|██▌       | 105/401 [40:55<1:56:04, 23.53s/it]
#
# Sampling chain 1, 0 divergences:  26%|██▋       | 106/401 [41:19<1:55:46, 23.55s/it]
#
# Sampling chain 1, 0 divergences:  27%|██▋       | 107/401 [41:41<1:53:47, 23.22s/it]
#
# Sampling chain 1, 0 divergences:  27%|██▋       | 108/401 [42:04<1:52:43, 23.08s/it]
#
# Sampling chain 1, 0 divergences:  27%|██▋       | 109/401 [42:27<1:52:28, 23.11s/it]
#
# Sampling chain 1, 0 divergences:  27%|██▋       | 110/401 [42:51<1:53:01, 23.30s/it]
#
# Sampling chain 1, 0 divergences:  28%|██▊       | 111/401 [43:15<1:52:54, 23.36s/it]
#
# Sampling chain 1, 0 divergences:  28%|██▊       | 112/401 [43:38<1:53:08, 23.49s/it]
#
# Sampling chain 1, 0 divergences:  28%|██▊       | 113/401 [44:02<1:53:07, 23.57s/it]
#
# Sampling chain 1, 0 divergences:  28%|██▊       | 114/401 [44:25<1:52:15, 23.47s/it]
#
# Sampling chain 1, 0 divergences:  29%|██▊       | 115/401 [44:48<1:51:01, 23.29s/it]
#
# Sampling chain 1, 0 divergences:  29%|██▉       | 116/401 [45:12<1:50:38, 23.29s/it]
#
# Sampling chain 1, 0 divergences:  29%|██▉       | 117/401 [45:34<1:49:12, 23.07s/it]
#
# Sampling chain 1, 0 divergences:  29%|██▉       | 118/401 [45:58<1:49:33, 23.23s/it]
#
# Sampling chain 1, 0 divergences:  30%|██▉       | 119/401 [46:21<1:49:07, 23.22s/it]
#
# Sampling chain 1, 0 divergences:  30%|██▉       | 120/401 [46:45<1:49:34, 23.40s/it]
#
# Sampling chain 1, 0 divergences:  30%|███       | 121/401 [47:08<1:49:30, 23.47s/it]
#
# Sampling chain 1, 0 divergences:  30%|███       | 122/401 [47:32<1:49:59, 23.65s/it]
#
# Sampling chain 1, 0 divergences:  31%|███       | 123/401 [47:55<1:48:18, 23.37s/it]
#
# Sampling chain 1, 0 divergences:  31%|███       | 124/401 [48:20<1:49:24, 23.70s/it]
#
# Sampling chain 1, 0 divergences:  31%|███       | 125/401 [48:43<1:48:36, 23.61s/it]
#
# Sampling chain 1, 0 divergences:  31%|███▏      | 126/401 [49:07<1:48:19, 23.63s/it]
#
# Sampling chain 1, 0 divergences:  32%|███▏      | 127/401 [49:30<1:46:44, 23.37s/it]
#
# Sampling chain 1, 0 divergences:  32%|███▏      | 128/401 [49:53<1:46:24, 23.39s/it]
#
# Sampling chain 1, 0 divergences:  32%|███▏      | 129/401 [50:16<1:45:56, 23.37s/it]
#
# Sampling chain 1, 0 divergences:  32%|███▏      | 130/401 [50:41<1:46:58, 23.68s/it]
#
# Sampling chain 1, 0 divergences:  33%|███▎      | 131/401 [51:05<1:47:01, 23.78s/it]
#
# Sampling chain 1, 0 divergences:  33%|███▎      | 132/401 [51:29<1:46:53, 23.84s/it]
#
# Sampling chain 1, 0 divergences:  33%|███▎      | 133/401 [51:53<1:46:49, 23.92s/it]
#
# Sampling chain 1, 0 divergences:  33%|███▎      | 134/401 [52:17<1:46:56, 24.03s/it]
#
# Sampling chain 1, 0 divergences:  34%|███▎      | 135/401 [52:40<1:44:43, 23.62s/it]
#
# Sampling chain 1, 0 divergences:  34%|███▍      | 136/401 [53:04<1:44:34, 23.68s/it]
#
# Sampling chain 1, 0 divergences:  34%|███▍      | 137/401 [53:27<1:43:35, 23.54s/it]
#
# Sampling chain 1, 0 divergences:  34%|███▍      | 138/401 [53:50<1:42:08, 23.30s/it]
#
# Sampling chain 1, 0 divergences:  35%|███▍      | 139/401 [54:13<1:42:09, 23.40s/it]
#
# Sampling chain 1, 0 divergences:  35%|███▍      | 140/401 [54:37<1:42:42, 23.61s/it]
#
# Sampling chain 1, 0 divergences:  35%|███▌      | 141/401 [55:01<1:42:39, 23.69s/it]
#
# Sampling chain 1, 0 divergences:  35%|███▌      | 142/401 [55:25<1:42:38, 23.78s/it]
#
# Sampling chain 1, 0 divergences:  36%|███▌      | 143/401 [55:49<1:42:06, 23.75s/it]
#
# Sampling chain 1, 0 divergences:  36%|███▌      | 144/401 [56:13<1:41:48, 23.77s/it]
#
# Sampling chain 1, 0 divergences:  36%|███▌      | 145/401 [56:35<1:40:14, 23.49s/it]
#
# Sampling chain 1, 0 divergences:  36%|███▋      | 146/401 [56:59<1:40:07, 23.56s/it]
#
# Sampling chain 1, 0 divergences:  37%|███▋      | 147/401 [57:24<1:40:43, 23.80s/it]
#
# Sampling chain 1, 0 divergences:  37%|███▋      | 148/401 [57:47<1:40:33, 23.85s/it]
#
# Sampling chain 1, 0 divergences:  37%|███▋      | 149/401 [58:11<1:40:03, 23.82s/it]
#
# Sampling chain 1, 0 divergences:  37%|███▋      | 150/401 [58:35<1:39:41, 23.83s/it]
#
# Sampling chain 1, 0 divergences:  38%|███▊      | 151/401 [58:59<1:39:05, 23.78s/it]
#
# ...
#
# Sampling chain 1, 0 divergences:  55%|█████▍    | 219/401 [1:24:53<1:09:26, 22.89s/it]
#
# Sampling chain 1, 0 divergences:  55%|█████▍    | 220/401 [1:25:15<1:08:36, 22.74s/it]
#
# Sampling chain 1, 0 divergences:  55%|█████▌    | 221/401 [1:25:38<1:08:31, 22.84s/it]
#
# Sampling chain 1, 0 divergences:  55%|█████▌    | 222/401 [1:26:01<1:07:47, 22.72s/it]
#
# Sampling chain 1, 0 divergences:  56%|█████▌    | 223/401 [1:26:24<1:07:28, 22.75s/it]
#
# Sampling chain 1, 0 divergences:  56%|█████▌    | 224/401 [1:26:46<1:07:01, 22.72s/it]
#
# Sampling chain 1, 0 divergences:  56%|█████▌    | 225/401 [1:27:09<1:06:34, 22.69s/it]
#
# Sampling chain 1, 0 divergences:  56%|█████▋    | 226/401 [1:27:32<1:06:33, 22.82s/it]
#
# Sampling chain 1, 0 divergences:  57%|█████▋    | 227/401 [1:27:55<1:06:13, 22.84s/it]
#
# Sampling chain 1, 0 divergences:  57%|█████▋    | 228/401 [1:28:19<1:06:27, 23.05s/it]
#
# Sampling chain 1, 0 divergences:  57%|█████▋    | 229/401 [1:28:42<1:05:59, 23.02s/it]
#
# Sampling chain 1, 0 divergences:  57%|█████▋    | 230/401 [1:29:05<1:06:14, 23.24s/it]
#
# Sampling chain 1, 0 divergences:  58%|█████▊    | 231/401 [1:29:29<1:05:54, 23.26s/it]
#
# Sampling chain 1, 0 divergences:  58%|█████▊    | 232/401 [1:29:52<1:05:24, 23.22s/it]
#
# Sampling chain 1, 0 divergences:  58%|█████▊    | 233/401 [1:30:14<1:04:32, 23.05s/it]
#
# Sampling chain 1, 0 divergences:  58%|█████▊    | 234/401 [1:30:38<1:04:16, 23.09s/it]
#
# Sampling chain 1, 0 divergences:  59%|█████▊    | 235/401 [1:31:04<1:06:21, 23.99s/it]
#
# Sampling chain 1, 0 divergences:  59%|█████▉    | 236/401 [1:31:29<1:07:06, 24.40s/it]
#
# Sampling chain 1, 0 divergences:  59%|█████▉    | 237/401 [1:31:53<1:06:15, 24.24s/it]
#
# Sampling chain 1, 0 divergences:  59%|█████▉    | 238/401 [1:32:18<1:06:46, 24.58s/it]
#
# Sampling chain 1, 0 divergences:  60%|█████▉    | 239/401 [1:32:43<1:06:47, 24.74s/it]
#
# Sampling chain 1, 0 divergences:  60%|█████▉    | 240/401 [1:33:07<1:05:42, 24.49s/it]
#
# Sampling chain 1, 0 divergences:  60%|██████    | 241/401 [1:33:30<1:03:52, 23.96s/it]
#
# Sampling chain 1, 0 divergences:  60%|██████    | 242/401 [1:33:53<1:03:03, 23.79s/it]
#
# Sampling chain 1, 0 divergences:  61%|██████    | 243/401 [1:34:17<1:02:41, 23.81s/it]
#
# Sampling chain 1, 0 divergences:  61%|██████    | 244/401 [1:34:40<1:01:51, 23.64s/it]
#
# Sampling chain 1, 0 divergences:  61%|██████    | 245/401 [1:35:04<1:01:42, 23.74s/it]
#
# Sampling chain 1, 0 divergences:  61%|██████▏   | 246/401 [1:35:28<1:01:30, 23.81s/it]
#
# Sampling chain 1, 0 divergences:  62%|██████▏   | 247/401 [1:35:52<1:00:51, 23.71s/it]
#
# Sampling chain 1, 0 divergences:  62%|██████▏   | 248/401 [1:36:16<1:01:01, 23.93s/it]
#
# Sampling chain 1, 0 divergences:  62%|██████▏   | 249/401 [1:36:43<1:02:37, 24.72s/it]
#
# Sampling chain 1, 0 divergences:  62%|██████▏   | 250/401 [1:37:07<1:02:03, 24.66s/it]
#
# Sampling chain 1, 0 divergences:  63%|██████▎   | 251/401 [1:37:32<1:01:15, 24.50s/it]
#
# Sampling chain 1, 0 divergences:  63%|██████▎   | 252/401 [1:37:55<1:00:21, 24.30s/it]
#
# Sampling chain 1, 0 divergences:  63%|██████▎   | 253/401 [1:38:19<59:29, 24.12s/it]
#
# Sampling chain 1, 0 divergences:  63%|██████▎   | 254/401 [1:38:43<58:48, 24.00s/it]
#
# Sampling chain 1, 0 divergences:  64%|██████▎   | 255/401 [1:39:07<58:21, 23.98s/it]
#
# Sampling chain 1, 0 divergences:  64%|██████▍   | 256/401 [1:39:30<57:44, 23.89s/it]
#
# Sampling chain 1, 0 divergences:  64%|██████▍   | 257/401 [1:39:53<56:33, 23.57s/it]
#
# Sampling chain 1, 0 divergences:  64%|██████▍   | 258/401 [1:40:17<56:04, 23.53s/it]
#
# Sampling chain 1, 0 divergences:  65%|██████▍   | 259/401 [1:40:40<55:47, 23.57s/it]
#
# Sampling chain 1, 0 divergences:  65%|██████▍   | 260/401 [1:41:04<55:37, 23.67s/it]
#
# Sampling chain 1, 0 divergences:  65%|██████▌   | 261/401 [1:41:28<55:14, 23.68s/it]
#
# Sampling chain 1, 0 divergences:  65%|██████▌   | 262/401 [1:41:51<54:32, 23.54s/it]
#
# Sampling chain 1, 0 divergences:  66%|██████▌   | 263/401 [1:42:15<54:29, 23.69s/it]
#
# Sampling chain 1, 0 divergences:  66%|██████▌   | 264/401 [1:42:39<54:12, 23.74s/it]
#
# Sampling chain 1, 0 divergences:  66%|██████▌   | 265/401 [1:43:02<53:26, 23.57s/it]
#
# Sampling chain 1, 0 divergences:  66%|██████▋   | 266/401 [1:43:25<52:47, 23.46s/it]
#
# Sampling chain 1, 0 divergences:  67%|██████▋   | 267/401 [1:43:49<52:12, 23.38s/it]
#
# Sampling chain 1, 0 divergences:  67%|██████▋   | 268/401 [1:44:13<52:29, 23.68s/it]
#
# Sampling chain 1, 0 divergences:  67%|██████▋   | 269/401 [1:44:37<52:11, 23.72s/it]
#
# Sampling chain 1, 0 divergences:  67%|██████▋   | 270/401 [1:45:00<51:39, 23.66s/it]
#
# Sampling chain 1, 0 divergences:  68%|██████▊   | 271/401 [1:45:24<51:32, 23.79s/it]
#
# Sampling chain 1, 0 divergences:  68%|██████▊   | 272/401 [1:45:49<51:32, 23.97s/it]
#
# Sampling chain 1, 0 divergences:  68%|██████▊   | 273/401 [1:46:13<51:00, 23.91s/it]
#
# Sampling chain 1, 0 divergences:  68%|██████▊   | 274/401 [1:46:37<50:46, 23.99s/it]
#
# Sampling chain 1, 0 divergences:  69%|██████▊   | 275/401 [1:47:00<49:38, 23.64s/it]
#
# Sampling chain 1, 0 divergences:  69%|██████▉   | 276/401 [1:47:23<49:18, 23.67s/it]
#
# Sampling chain 1, 0 divergences:  69%|██████▉   | 277/401 [1:47:47<48:55, 23.67s/it]
#
# Sampling chain 1, 0 divergences:  69%|██████▉   | 278/401 [1:48:11<48:27, 23.63s/it]
#
# Sampling chain 1, 0 divergences:  70%|██████▉   | 279/401 [1:48:34<47:55, 23.57s/it]
#
# Sampling chain 1, 0 divergences:  70%|██████▉   | 280/401 [1:48:58<47:46, 23.69s/it]
#
# Sampling chain 1, 0 divergences:  70%|███████   | 281/401 [1:49:22<47:17, 23.65s/it]
#
# Sampling chain 1, 0 divergences:  70%|███████   | 282/401 [1:49:46<47:31, 23.96s/it]
#
# Sampling chain 1, 0 divergences:  71%|███████   | 283/401 [1:50:11<47:44, 24.28s/it]
#
# Sampling chain 1, 0 divergences:  71%|███████   | 284/401 [1:50:37<48:04, 24.65s/it]
#
# Sampling chain 1, 0 divergences:  71%|███████   | 285/401 [1:51:04<49:03, 25.37s/it]
#
# Sampling chain 1, 0 divergences:  71%|███████▏  | 286/401 [1:51:31<49:43, 25.94s/it]
#
# Sampling chain 1, 0 divergences:  72%|███████▏  | 287/401 [1:51:58<49:47, 26.21s/it]
#
# Sampling chain 1, 0 divergences:  72%|███████▏  | 288/401 [1:52:25<49:44, 26.41s/it]
#
# Sampling chain 1, 0 divergences:  72%|███████▏  | 289/401 [1:52:51<49:00, 26.25s/it]
#
# Sampling chain 1, 0 divergences:  72%|███████▏  | 290/401 [1:53:17<48:33, 26.24s/it]
#
# Sampling chain 1, 0 divergences:  73%|███████▎  | 291/401 [1:53:43<48:08, 26.26s/it]
#
# Sampling chain 1, 0 divergences:  73%|███████▎  | 292/401 [1:54:09<47:39, 26.24s/it]
#
# Sampling chain 1, 0 divergences:  73%|███████▎  | 293/401 [1:54:36<47:25, 26.35s/it]
#
# Sampling chain 1, 0 divergences:  73%|███████▎  | 294/401 [1:55:02<46:36, 26.14s/it]
#
# Sampling chain 1, 0 divergences:  74%|███████▎  | 295/401 [1:55:28<46:21, 26.24s/it]
#
# Sampling chain 1, 0 divergences:  74%|███████▍  | 296/401 [1:55:54<45:44, 26.14s/it]
#
# Sampling chain 1, 0 divergences:  74%|███████▍  | 297/401 [1:56:20<45:21, 26.17s/it]
#
# Sampling chain 1, 0 divergences:  74%|███████▍  | 298/401 [1:56:46<44:36, 25.99s/it]
#
# Sampling chain 1, 0 divergences:  75%|███████▍  | 299/401 [1:57:12<44:32, 26.20s/it]
#
# Sampling chain 1, 0 divergences:  75%|███████▍  | 300/401 [1:57:39<44:13, 26.27s/it]
#
# Sampling chain 1, 0 divergences:  75%|███████▌  | 301/401 [1:58:05<43:53, 26.33s/it]
#
# Sampling chain 1, 0 divergences:  75%|███████▌  | 302/401 [1:58:32<43:37, 26.44s/it]
#
# Sampling chain 1, 0 divergences:  76%|███████▌  | 303/401 [1:58:58<42:58, 26.31s/it]
#
# Sampling chain 1, 0 divergences:  76%|███████▌  | 304/401 [1:59:25<42:44, 26.43s/it]
#
# Sampling chain 1, 0 divergences:  76%|███████▌  | 305/401 [1:59:51<42:03, 26.29s/it]
#
# Sampling chain 1, 0 divergences:  76%|███████▋  | 306/401 [2:00:16<41:00, 25.90s/it]
#
# Sampling chain 1, 0 divergences:  77%|███████▋  | 307/401 [2:00:39<39:15, 25.06s/it]
#
# Sampling chain 1, 0 divergences:  77%|███████▋  | 308/401 [2:01:02<37:49, 24.40s/it]
#
# Sampling chain 1, 0 divergences:  77%|███████▋  | 309/401 [2:01:24<36:32, 23.83s/it]
#
# Sampling chain 1, 0 divergences:  77%|███████▋  | 310/401 [2:01:48<35:59, 23.73s/it]
#
# Sampling chain 1, 0 divergences:  78%|███████▊  | 311/401 [2:02:12<36:00, 24.00s/it]
#
# Sampling chain 1, 0 divergences:  78%|███████▊  | 312/401 [2:02:38<36:14, 24.43s/it]
#
# Sampling chain 1, 0 divergences:  78%|███████▊  | 313/401 [2:03:03<36:05, 24.61s/it]
#
# Sampling chain 1, 0 divergences:  78%|███████▊  | 314/401 [2:03:28<36:00, 24.84s/it]
#
# Sampling chain 1, 0 divergences:  79%|███████▊  | 315/401 [2:03:52<35:17, 24.63s/it]
#
# Sampling chain 1, 0 divergences:  79%|███████▉  | 316/401 [2:04:17<34:48, 24.58s/it]
#
# Sampling chain 1, 0 divergences:  79%|███████▉  | 317/401 [2:04:41<34:13, 24.44s/it]
#
# Sampling chain 1, 0 divergences:  79%|███████▉  | 318/401 [2:05:05<33:48, 24.45s/it]
#
# Sampling chain 1, 0 divergences:  80%|███████▉  | 319/401 [2:05:30<33:35, 24.58s/it]
#
# Sampling chain 1, 0 divergences:  80%|███████▉  | 320/401 [2:05:55<33:09, 24.56s/it]
#
# Sampling chain 1, 0 divergences:  80%|████████  | 321/401 [2:06:19<32:38, 24.48s/it]
#
# Sampling chain 1, 0 divergences:  80%|████████  | 322/401 [2:06:43<31:52, 24.21s/it]
#
# Sampling chain 1, 0 divergences:  81%|████████  | 323/401 [2:07:06<31:17, 24.07s/it]
#
# Sampling chain 1, 0 divergences:  81%|████████  | 324/401 [2:07:30<30:40, 23.90s/it]
#
# Sampling chain 1, 0 divergences:  81%|████████  | 325/401 [2:07:54<30:24, 24.01s/it]
#
# Sampling chain 1, 0 divergences:  81%|████████▏ | 326/401 [2:08:18<30:01, 24.02s/it]
#
# Sampling chain 1, 0 divergences:  82%|████████▏ | 327/401 [2:08:42<29:23, 23.83s/it]
#
# Sampling chain 1, 0 divergences:  82%|████████▏ | 328/401 [2:09:05<28:57, 23.81s/it]
#
# Sampling chain 1, 0 divergences:  82%|████████▏ | 329/401 [2:09:29<28:38, 23.87s/it]
#
# Sampling chain 1, 0 divergences:  82%|████████▏ | 330/401 [2:09:54<28:29, 24.08s/it]
#
# Sampling chain 1, 0 divergences:  83%|████████▎ | 331/401 [2:10:19<28:30, 24.43s/it]
#
# Sampling chain 1, 0 divergences:  83%|████████▎ | 332/401 [2:10:44<28:20, 24.65s/it]
#
# Sampling chain 1, 0 divergences:  83%|████████▎ | 333/401 [2:11:10<28:21, 25.02s/it]
#
# Sampling chain 1, 0 divergences:  83%|████████▎ | 334/401 [2:11:35<27:55, 25.01s/it]
#
# Sampling chain 1, 0 divergences:  84%|████████▎ | 335/401 [2:12:00<27:18, 24.83s/it]
#
# Sampling chain 1, 0 divergences:  84%|████████▍ | 336/401 [2:12:24<26:50, 24.78s/it]
#
# Sampling chain 1, 0 divergences:  84%|████████▍ | 337/401 [2:12:50<26:38, 24.97s/it]
#
# Sampling chain 1, 0 divergences:  84%|████████▍ | 338/401 [2:13:14<25:59, 24.76s/it]
#
# Sampling chain 1, 0 divergences:  85%|████████▍ | 339/401 [2:13:39<25:40, 24.85s/it]
#
# Sampling chain 1, 0 divergences:  85%|████████▍ | 340/401 [2:14:05<25:29, 25.07s/it]
#
# Sampling chain 1, 0 divergences:  85%|████████▌ | 341/401 [2:14:30<25:02, 25.03s/it]
#
# Sampling chain 1, 0 divergences:  85%|████████▌ | 342/401 [2:14:55<24:40, 25.10s/it]
#
# Sampling chain 1, 0 divergences:  86%|████████▌ | 343/401 [2:15:19<24:03, 24.89s/it]
#
# Sampling chain 1, 0 divergences:  86%|████████▌ | 344/401 [2:15:44<23:31, 24.76s/it]
#
# Sampling chain 1, 0 divergences:  86%|████████▌ | 345/401 [2:16:08<22:56, 24.57s/it]
#
# Sampling chain 1, 0 divergences:  86%|████████▋ | 346/401 [2:16:32<22:21, 24.39s/it]
#
# Sampling chain 1, 0 divergences:  87%|████████▋ | 347/401 [2:16:56<21:56, 24.38s/it]
#
# Sampling chain 1, 0 divergences:  87%|████████▋ | 348/401 [2:17:21<21:36, 24.46s/it]
#
# Sampling chain 1, 0 divergences:  87%|████████▋ | 349/401 [2:17:46<21:19, 24.60s/it]
#
# Sampling chain 1, 0 divergences:  87%|████████▋ | 350/401 [2:18:10<20:56, 24.64s/it]
#
# Sampling chain 1, 0 divergences:  88%|████████▊ | 351/401 [2:18:35<20:34, 24.70s/it]
#
# Sampling chain 1, 0 divergences:  88%|████████▊ | 352/401 [2:18:59<20:01, 24.52s/it]
#
# Sampling chain 1, 0 divergences:  88%|████████▊ | 353/401 [2:19:24<19:32, 24.42s/it]
#
# Sampling chain 1, 0 divergences:  88%|████████▊ | 354/401 [2:19:48<19:01, 24.29s/it]
#
# Sampling chain 1, 0 divergences:  89%|████████▊ | 355/401 [2:20:12<18:34, 24.22s/it]
#
# Sampling chain 1, 0 divergences:  89%|████████▉ | 356/401 [2:20:37<18:22, 24.50s/it]
#
# Sampling chain 1, 0 divergences:  89%|████████▉ | 357/401 [2:21:02<18:04, 24.65s/it]
#
# Sampling chain 1, 0 divergences:  89%|████████▉ | 358/401 [2:21:26<17:38, 24.62s/it]
#
# Sampling chain 1, 0 divergences:  90%|████████▉ | 359/401 [2:21:51<17:12, 24.58s/it]
#
# Sampling chain 1, 0 divergences:  90%|████████▉ | 360/401 [2:22:15<16:44, 24.49s/it]
#
# Sampling chain 1, 0 divergences:  90%|█████████ | 361/401 [2:22:39<16:17, 24.43s/it]
#
# Sampling chain 1, 0 divergences:  90%|█████████ | 362/401 [2:23:03<15:46, 24.27s/it]
#
# Sampling chain 1, 0 divergences:  91%|█████████ | 363/401 [2:23:28<15:23, 24.30s/it]
#
# Sampling chain 1, 0 divergences:  91%|█████████ | 364/401 [2:23:53<15:07, 24.53s/it]
#
# Sampling chain 1, 0 divergences:  91%|█████████ | 365/401 [2:24:18<14:55, 24.89s/it]
#
# Sampling chain 1, 0 divergences:  91%|█████████▏| 366/401 [2:24:42<14:21, 24.61s/it]
#
# Sampling chain 1, 0 divergences:  92%|█████████▏| 367/401 [2:25:07<13:59, 24.69s/it]
#
# Sampling chain 1, 0 divergences:  92%|█████████▏| 368/401 [2:25:32<13:34, 24.68s/it]
#
# Sampling chain 1, 0 divergences:  92%|█████████▏| 369/401 [2:25:57<13:10, 24.69s/it]
#
# Sampling chain 1, 0 divergences:  92%|█████████▏| 370/401 [2:26:21<12:39, 24.50s/it]
#
# Sampling chain 1, 0 divergences:  93%|█████████▎| 371/401 [2:26:45<12:11, 24.38s/it]
#
# Sampling chain 1, 0 divergences:  93%|█████████▎| 372/401 [2:27:09<11:47, 24.40s/it]
#
# Sampling chain 1, 0 divergences:  93%|█████████▎| 373/401 [2:27:34<11:22, 24.39s/it]
#
# Sampling chain 1, 0 divergences:  93%|█████████▎| 374/401 [2:27:58<11:00, 24.45s/it]
#
# Sampling chain 1, 0 divergences:  94%|█████████▎| 375/401 [2:28:22<10:32, 24.33s/it]
#
# Sampling chain 1, 0 divergences:  94%|█████████▍| 376/401 [2:28:46<10:04, 24.18s/it]
#
# Sampling chain 1, 0 divergences:  94%|█████████▍| 377/401 [2:29:10<09:37, 24.07s/it]
#
# Sampling chain 1, 0 divergences:  94%|█████████▍| 378/401 [2:29:34<09:14, 24.10s/it]
#
# Sampling chain 1, 0 divergences:  95%|█████████▍| 379/401 [2:29:59<08:57, 24.44s/it]
#
# Sampling chain 1, 0 divergences:  95%|█████████▍| 380/401 [2:30:24<08:36, 24.61s/it]
#
# Sampling chain 1, 0 divergences:  95%|█████████▌| 381/401 [2:30:49<08:12, 24.65s/it]
#
# Sampling chain 1, 0 divergences:  95%|█████████▌| 382/401 [2:31:14<07:49, 24.70s/it]
#
# Sampling chain 1, 0 divergences:  96%|█████████▌| 383/401 [2:31:39<07:27, 24.88s/it]
#
# Sampling chain 1, 0 divergences:  96%|█████████▌| 384/401 [2:32:04<07:00, 24.75s/it]
#
# Sampling chain 1, 0 divergences:  96%|█████████▌| 385/401 [2:32:28<06:32, 24.52s/it]
#
# Sampling chain 1, 0 divergences:  96%|█████████▋| 386/401 [2:32:52<06:06, 24.43s/it]
#
# Sampling chain 1, 0 divergences:  97%|█████████▋| 387/401 [2:33:15<05:38, 24.21s/it]
#
# Sampling chain 1, 0 divergences:  97%|█████████▋| 388/401 [2:33:40<05:14, 24.18s/it]
# Sampling chain 1, 0 divergences:  97%|█████████▋| 389/401 [2:34:03<04:47, 23.92s/it]
#
# Sampling chain 1, 0 divergences:  97%|█████████▋| 390/401 [2:34:27<04:24, 24.01s/it]
#
# Sampling chain 1, 0 divergences:  98%|█████████▊| 391/401 [2:34:51<03:59, 23.97s/it]
#
# Sampling chain 1, 0 divergences:  98%|█████████▊| 392/401 [2:35:15<03:34, 23.88s/it]
#
# Sampling chain 1, 0 divergences:  98%|█████████▊| 393/401 [2:35:39<03:12, 24.10s/it]
#
# Sampling chain 1, 0 divergences:  98%|█████████▊| 394/401 [2:36:04<02:49, 24.22s/it]
#
# Sampling chain 1, 0 divergences:  99%|█████████▊| 395/401 [2:36:27<02:24, 24.02s/it]
#
# Sampling chain 1, 0 divergences:  99%|█████████▉| 396/401 [2:36:51<01:59, 23.89s/it]
#
# Sampling chain 1, 0 divergences:  99%|█████████▉| 397/401 [2:37:16<01:37, 24.30s/it]
#
# Sampling chain 1, 0 divergences:  99%|█████████▉| 398/401 [2:37:41<01:13, 24.34s/it]
#
# Sampling chain 1, 0 divergences: 100%|█████████▉| 399/401 [2:38:05<00:48, 24.30s/it]
#
# Sampling chain 1, 0 divergences: 100%|█████████▉| 400/401 [2:38:28<00:24, 24.11s/it]
#
# Sampling chain 1, 0 divergences: 100%|██████████| 401/401 [2:38:53<00:00, 24.31s/it]
#
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
plot_traces(trace)
# Out:
# /Users/pablovargas/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/pablovargas/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/pablovargas/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/pablovargas/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/pablovargas/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/pablovargas/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/pablovargas/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/pablovargas/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/pablovargas/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/pablovargas/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/pablovargas/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"
# /Users/pablovargas/anaconda3/lib/python3.7/site-packages/arviz/plots/backends/matplotlib/distplot.py:38: UserWarning: Argument backend_kwargs has not effect in matplotlib.plot_distSupplied value won't be used
#   "Argument backend_kwargs has not effect in matplotlib.plot_dist"

# %% [markdown]
# #### NUTS sampler
# Use pm.sample without specifying a particular sampling method (pymc3 will choose it automatically).
# The sampling algorithm that will be used in this case is NUTS, which is a form of Hamiltonian Monte Carlo, in which parameters are tuned automatically. This is an advanced method that we hadn't cover in the lectures, but it usually converges faster and gives less correlated samples compared to vanilla Metropolis-Hastings.

# %%
with pm.Model() as logistic_model:
    # Train Bayesian logistic regression model on the following features: sex, age, age_squared, educ, hours
    # Use pm.sample to run MCMC to train this model.
    # Train your model for 400 samples.
    # Training can take a while, so relax and wait :)
    data['age2'] = data['age']**2
    pm.glm.GLM.from_formula("income_more_50K ~ sex + age + age2 + educ + hours", data, family='binomial')
    trace = pm.sample(draws=400, init = 'adapt_diag')
# Out:
# Only 400 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [hours, educ, age2, age, sex[T. Male], Intercept]
# Sampling 4 chains, 0 divergences:   9%|▉         | 333/3600 [12:04:48<113:48:05, 125.40s/draws]

# %%
plot_traces(trace)

# %% [markdown]
# #### Estimating the odds ratio
# Now, let's build the posterior distribution on the odds ratio given the dataset (approximated by MCMC).

# %%
# We don't need to use a large burn-in here, since we initialize sampling
# from a good point (from our approximation of the most probable
# point (MAP) to be more precise).
burnin = 100
b = trace['sex[T. Male]'][burnin:]
plt.hist(np.exp(b), bins=20, normed=True)
plt.xlabel("Odds Ratio")
plt.show()
# Out:
# /Users/pablovargas/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.

# %% [markdown]
# Finally, we can find a credible interval  (recall that credible intervals are Bayesian and confidence intervals are frequentist) for this quantity. This may be the best part about Bayesian statistics: we get to interpret credibility intervals the way we've always wanted to interpret them. We are 95% confident that the odds ratio lies within our interval!

# %%
lb, ub = np.percentile(b, 2.5), np.percentile(b, 97.5)
print("P(%.3f < Odds Ratio < %.3f) = 0.95" % (np.exp(lb), np.exp(ub)))
# Out:
# P(2.502 < Odds Ratio < 3.822) = 0.95

# %%
# Submit the obtained credible interval.
grader.submit_pymc_odds_ratio_interval(np.exp(lb), np.exp(ub))
# Out:
# Current answer for task 2.2 (credible interval lower bound) is: 2.5024065485985987
# Current answer for task 2.2 (credible interval upper bound) is: 3.8221128704219227

# %% [markdown]
# ### Task 2.3 interpreting the results

# %%
# Does the gender affects salary in the provided dataset?
# (Note that the data is from 1996 and maybe not representative
# of the current situation in the world.)
POSSIBLE_ANSWERS = {
    0: 'No, there is certainly no discrimination',
    1: 'We cannot say for sure',
    2: 'Yes, we are 95% sure that a female is *less* likely to get >$50K than a male with the same age, level of education, etc.', 
    3: 'Yes, we are 95% sure that a female is *more* likely to get >$50K than a male with the same age, level of education, etc.', 
}

idx = 2
answer = POSSIBLE_ANSWERS[idx]
grader.submit_is_there_discrimination(answer)
# Out:
# Current answer for task 2.3 (does the data suggest gender discrimination?) is: Yes, we are 95% sure that a female is *less* likely to get >$50K than a male with the same age, level of education, etc.

# %% [markdown]
# # Authorization & Submission
# To submit assignment parts to Cousera platform, please, enter your e-mail and token into variables below. You can generate a token on this programming assignment's page. <b>Note:</b> The token expires 30 minutes after generation.

# %%
STUDENT_EMAIL = 'X'
STUDENT_TOKEN = 'X'
grader.status()
# Out:
# You want to submit these numbers:
# Task 1.1 (Alice trajectory): 279.93428306022463  291.67686875834846
# Task 1.1 (Bob trajectory): 314.5384966605577  345.2425410740984
# Task 1.2 (Alice mean): 278.85416992423353
# Task 1.2 (Bob mean): 314.6064116545574
# Task 1.3 (Bob and Alice prices correlation): 0.9636099866766943
# Task 1.4 (depends on the random data or not): Does not depend on random seed and starting prices
# Task 2.1 (MAP for age coef): 0.04348244
# Task 2.1 (MAP for aducation coef): 0.3621089
# Task 2.2 (credible interval lower bound): 2.5024065485985987
# Task 2.2 (credible interval upper bound): 3.8221128704219227
# Task 2.3 (does the data suggest gender discrimination?): Yes, we are 95% sure that a female is *less* likely to get >$50K than a male with the same age, level of education, etc.

# %% [markdown]
# If you want to submit these answers, run cell below

# %%
grader.submit(STUDENT_EMAIL, STUDENT_TOKEN)
# Out:
# Submitted to Coursera platform. See results on assignment page!

# %% [markdown]
# # (Optional) generating videos of sampling process
# In this part you will generate videos showing the sampling process.

# %% [markdown]
# ### Setting things up
# You don't need to modify the code below, it sets up the plotting functions. The code is based on [MCMC visualization tutorial](https://twiecki.github.io/blog/2014/01/02/visualizing-mcmc/).

# %%
from IPython.display import HTML

# Number of MCMC iteration to animate.
samples = 400

figsize(6, 6)
fig = plt.figure()
s_width = (0.81, 1.29)
a_width = (0.11, 0.39)
samples_width = (0, samples)
ax1 = fig.add_subplot(221, xlim=s_width, ylim=samples_width)
ax2 = fig.add_subplot(224, xlim=samples_width, ylim=a_width)
ax3 = fig.add_subplot(223, xlim=s_width, ylim=a_width,
                      xlabel='male coef',
                      ylabel='educ coef')
fig.subplots_adjust(wspace=0.0, hspace=0.0)
line1, = ax1.plot([], [], lw=1)
line2, = ax2.plot([], [], lw=1)
line3, = ax3.plot([], [], 'o', lw=2, alpha=.1)
line4, = ax3.plot([], [], lw=1, alpha=.3)
line5, = ax3.plot([], [], 'k', lw=1)
line6, = ax3.plot([], [], 'k', lw=1)
ax1.set_xticklabels([])
ax2.set_yticklabels([])
lines = [line1, line2, line3, line4, line5, line6]

def init():
    for line in lines:
        line.set_data([], [])
    return lines

def animate(i):
    with logistic_model:
        if i == 0:
            # Burnin
            for j in range(samples): iter_sample.__next__() 
        trace = iter_sample.__next__()
    line1.set_data(trace['sex[T. Male]'][::-1], range(len(trace['sex[T. Male]'])))
    line2.set_data(range(len(trace['educ'])), trace['educ'][::-1])
    line3.set_data(trace['sex[T. Male]'], trace['educ'])
    line4.set_data(trace['sex[T. Male]'], trace['educ'])
    male = trace['sex[T. Male]'][-1]
    educ = trace['educ'][-1]
    line5.set_data([male, male], [educ, a_width[1]])
    line6.set_data([male, s_width[1]], [educ, educ])
    return lines

# %% [markdown]
# ## Animating Metropolis-Hastings

# %%
with pm.Model() as logistic_model:
    # Again define Bayesian logistic regression model on the following features: sex, age, age_squared, educ, hours
    
    #### YOUR CODE HERE ####
    
    ### END OF YOUR CODE ###
    step = pm.Metropolis()
    iter_sample = pm.iter_sample(2 * samples, step, start=map_estimate)
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=samples, interval=5, blit=True)
HTML(anim.to_html5_video())
# Note that generating the video may take a while.

# %% [markdown]
# ## Animating NUTS
# Now rerun the animation providing the NUTS sampling method as the step argument.
